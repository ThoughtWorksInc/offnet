# %%
import abc

# %%
import mmh3

# %%
import functools

# %%
import iteration_utilities

# %%
import random

# %%
import numpy as np

# %%
import math

# %%
import tensorflow as tf

# %%
from tensorflow.python import debug as tf_debug

# %%
from enum import IntEnum

# %%
print("TensorFlow version: {}".format(tf.VERSION))
# Out:
# TensorFlow version: 1.8.0

# %%
# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
training_data, testing_data = tf.keras.datasets.fashion_mnist.load_data()

# %%
number_of_classes = np.max(testing_data[1]).__int__() + 1
number_of_input_channels = 1

# %%
number_of_hidden_layers = 101

# %%
number_of_computing_layers = number_of_hidden_layers + number_of_classes

# %%
number_of_layers = number_of_input_channels + number_of_computing_layers

# %%
preferred_number_samples_per_layer = number_of_layers # All the previous layers

# %%
paddings = (0, 0), (2, 2), (2, 2)

# %%
random_seed = number_of_hidden_layers

# %%
weight_scale = 1.0

# %%
dense_weight_size = (number_of_layers + number_of_input_channels) * (number_of_layers - number_of_input_channels) // 2
print(dense_weight_size)
# Out:
# 6271

# %%
def grid_sample(images, offset_x, offset_y):
    tf.assert_rank(images, 3)
    image_shape = tf.shape(images)
    current_batch_size = image_shape[0]
    width = image_shape[1]
    height = image_shape[2]
    
    def check_width(tensor):
        if (tf.test.is_gpu_available()):
            return tensor
        else:
            return tf.maximum(tf.minimum(tensor, width - 1), 0)
    
    def check_height(tensor):
        if (tf.test.is_gpu_available()):
            return tensor
        else:
            return tf.maximum(tf.minimum(tensor, height - 1), 0)
    
    offset_left = tf.floor(offset_x)
    offset_top = tf.floor(offset_y)
    tf.assert_equal(tf.shape(offset_left), image_shape)
    tf.assert_equal(tf.shape(offset_top), image_shape)

    
    eps = 1e-7

    factor_right = offset_x - offset_left + eps
    factor_left = 1.0 + 2.0 * eps - factor_right
    factor_bottom = offset_y - offset_top + eps
    factor_top = 1.0 + 2.0 * eps - factor_bottom
    
    image_index, x_index, y_index = tf.meshgrid(
        tf.range(current_batch_size, dtype=tf.int32),
        tf.range(width, dtype=tf.int32),
        tf.range(height, dtype=tf.int32),
        indexing='ij',
    )
    
    tf.assert_equal(tf.shape(image_index), image_shape)
    tf.assert_equal(tf.shape(x_index), image_shape)
    tf.assert_equal(tf.shape(y_index), image_shape)

    
    left_index = check_width(x_index + tf.cast(offset_left, tf.int32))
    top_index = check_height(y_index + tf.cast(offset_top, tf.int32))

    right_index = left_index + 1
    bottom_index = top_index + 1
    
    tf.assert_equal(tf.shape(left_index), image_shape)
    tf.assert_equal(tf.shape(top_index), image_shape)
    tf.assert_equal(tf.shape(right_index), image_shape)
    tf.assert_equal(tf.shape(bottom_index), image_shape)    
    
    tf.assert_rank(left_index, 3)
    tf.assert_rank(right_index, 3)
    tf.assert_rank(bottom_index, 3)
    tf.assert_rank(top_index, 3)
    
    images_top_left = tf.gather_nd(images, tf.stack((image_index, left_index, top_index), axis=3))
    images_top_right = tf.gather_nd(images, tf.stack((image_index, right_index, top_index), axis=3))
    images_bottom_left = tf.gather_nd(images, tf.stack((image_index, left_index, bottom_index), axis=3))
    images_bottom_right = tf.gather_nd(images, tf.stack((image_index, right_index, bottom_index), axis=3))

    tf.assert_rank(images_top_left, 3)
    tf.assert_rank(images_top_right, 3)
    tf.assert_rank(images_bottom_left, 3)
    tf.assert_rank(images_bottom_right, 3)

    lerp_top = factor_left * images_top_left + factor_right * images_top_right
    lerp_bottom = factor_left * images_bottom_left + factor_right * images_bottom_right
    output = factor_top * lerp_top + factor_bottom * lerp_bottom
    tf.assert_rank(output, 3)
    return output

# %%
def model_fn(features, labels, mode, params, config):
    random.seed(number_of_hidden_layers)
    padded_input = tf.pad(tf.cast(features, tf.float32) / 255.0 - 0.5, paddings)
        
    score_weight = tf.get_variable(
        name="score_weight",
        initializer=tf.random_normal_initializer(),
        dtype=tf.float32,
        shape=(dense_weight_size, )
    )
    offset_x_weight = tf.get_variable(
        name="offset_x_weight",
        initializer=tf.random_normal_initializer(),
        dtype=tf.float32,
        shape=(dense_weight_size, )
    )
    offset_y_weight = tf.get_variable(
        name="offset_y_weight",
        initializer=tf.random_normal_initializer(),
        dtype=tf.float32,
        shape=(dense_weight_size, )
    )
    score_bias = tf.get_variable(
        name="score_bias",
        initializer=tf.zeros_initializer(),
        dtype=tf.float32,
        shape=(number_of_layers, ),
    )
    offset_x_bias = tf.get_variable(
        name="offset_x_bias",
        initializer=tf.random_uniform_initializer(minval=-3.0, maxval=3.0),
        dtype=tf.float32,
        shape=(number_of_layers, ),
    )
    offset_y_bias = tf.get_variable(
        name="offset_y_bias",
        initializer=tf.random_uniform_initializer(minval=-3.0, maxval=3.0),
        dtype=tf.float32,
        shape=(number_of_layers, ),
    )
    score_scale = tf.get_variable(
        name="score_scale",
        initializer=tf.sqrt(weight_scale / (tf.range(number_of_layers, dtype=tf.float32) + tf.constant(1e-10))),
        dtype=tf.float32
    )
    offset_x_scale = tf.get_variable(
        name="offset_x_scale",
        initializer=tf.sqrt(weight_scale / (tf.range(number_of_layers, dtype=tf.float32) + tf.constant(1e-10))),
        dtype=tf.float32
    )
    offset_y_scale = tf.get_variable(
        name="offset_y_scale",
        initializer=tf.sqrt(weight_scale / (tf.range(number_of_layers, dtype=tf.float32) + tf.constant(1e-10))),
        dtype=tf.float32
    )
    

    def score_map(previous_layers, number_of_previous_layers, next_layer_id):
        weight_start = (number_of_input_channels + next_layer_id) * (next_layer_id - number_of_input_channels) // 2
        weight_end = weight_start + number_of_previous_layers
        tf.assert_rank(weight_start, 0)
        
        # TODO test if the performance improves when using SparseTensor
        previous_layer_tensor = previous_layers.gather(tf.range(number_of_previous_layers))
        tf.assert_rank(previous_layer_tensor, 4)

        def indexed_sum(weight, bias, scale):
            tf.assert_rank(weight, 1)
            weight_slice = weight[weight_start:weight_end] * scale[next_layer_id]

            tf.assert_equal(tf.shape(weight_slice)[0], tf.shape(previous_layer_tensor)[0])
            return tf.tensordot(
                weight_slice,
                previous_layer_tensor,
                axes=1
            ) + bias[next_layer_id]

        return grid_sample(
            indexed_sum(score_weight, score_bias, score_scale),
            indexed_sum(offset_x_weight, offset_x_bias, offset_x_scale),
            indexed_sum(offset_y_weight, offset_y_bias, offset_y_scale),
        )

    layers, i = tf.while_loop(
        lambda layers, i: i < number_of_layers,
        lambda layers, i: (
            layers.write(i,
                score_map(
                    layers,
                    number_of_previous_layers=number_of_input_channels + number_of_hidden_layers,
                    next_layer_id=i
                )
            ),
            i + 1
        ),
        tf.while_loop(
            lambda layers, i: i < number_of_input_channels + number_of_hidden_layers,
            lambda layers, i: (layers.write(i, score_map(layers, i, i)), i + 1),
            (
                tf.TensorArray(tf.float32, size=number_of_layers, clear_after_read=False, infer_shape=True).write(
                    0,
                    padded_input,
                ),
                tf.constant(number_of_input_channels),
            )
        )
    )

    tf.assert_equal(i, tf.cast(number_of_layers, tf.int32))

    scores_per_pixel = layers.gather(tf.range(number_of_layers - number_of_classes, number_of_layers, dtype=tf.int32))
    score_shape = tf.shape(scores_per_pixel)
    scores = tf.transpose(scores_per_pixel[:, :, score_shape[2] // 2, score_shape[3] // 2])
    probabilities = tf.nn.softmax(logits=scores)
    predicted_classes = tf.argmax(scores, 1)
    predictions = {
        'probabilities' : probabilities,
        'scores': scores,
        'class': predicted_classes,
    }
    global_step = tf.train.get_global_step()
    optimizer = tf.train.RMSPropOptimizer(learning_rate=0.01)
    if labels is None:
        return tf.estimator.EstimatorSpec(
            mode=mode,
            predictions=predictions,
        )
    else:
        loss = tf.losses.softmax_cross_entropy(logits=scores, onehot_labels=tf.one_hot(labels, number_of_classes))
        eval_metric_ops = {
            'accuracy': tf.metrics.accuracy(labels=labels, predictions=predicted_classes)
        }
        return tf.estimator.EstimatorSpec(
            mode=mode,
            predictions=predictions,
            loss=loss,
            train_op=optimizer.minimize(loss, global_step=global_step),
            eval_metric_ops=eval_metric_ops,
        )

# %%
run_config = tf.estimator.RunConfig(
    model_dir=f"models/rmspropoffnet{number_of_hidden_layers}",
    session_config=tf.ConfigProto(
        gpu_options=tf.GPUOptions(
            allow_growth=True,
        ),
        graph_options=tf.GraphOptions(
            optimizer_options=tf.OptimizerOptions(
                global_jit_level=tf.OptimizerOptions.ON_2,
                do_function_inlining=True,
                do_constant_folding=True,
                do_common_subexpression_elimination=True,
            ),
        )
    )
)

# %%
estimator = tf.estimator.Estimator(model_fn, config=run_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'models/rmspropoffnet101', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   allow_growth: true
# }
# graph_options {
#   optimizer_options {
#     do_common_subexpression_elimination: true
#     do_constant_folding: true
#     do_function_inlining: true
#     global_jit_level: ON_2
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f17a42862b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x7f17a7734620>) includes params argument, but params are not passed to Estimator.

# %%
batch_size = 32

# %%
def training_dataset():
    return tf.data.Dataset.from_tensor_slices(training_data).shuffle(1000).batch(batch_size)

# %%
def testing_dataset():
    return tf.data.Dataset.from_tensor_slices(testing_data).batch(batch_size)

# %%
# hook = tf_debug.TensorBoardDebugHook("localhost:6064")
# estimator.train(training_dataset,hooks=[hook])

# %%
tf.estimator.train_and_evaluate(
    estimator,
    train_spec=tf.estimator.TrainSpec(training_dataset),
    eval_spec=tf.estimator.EvalSpec(testing_dataset)
)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 2.3310604, step = 0
# INFO:tensorflow:global_step/sec: 2.25199
# INFO:tensorflow:loss = 0.70822066, step = 100 (44.406 sec)
# INFO:tensorflow:global_step/sec: 2.29548
# INFO:tensorflow:loss = 0.86312073, step = 200 (43.563 sec)
# INFO:tensorflow:global_step/sec: 2.30422
# INFO:tensorflow:loss = 0.77628493, step = 300 (43.400 sec)
# INFO:tensorflow:global_step/sec: 2.34272
# INFO:tensorflow:loss = 0.713781, step = 400 (42.685 sec)
# INFO:tensorflow:global_step/sec: 2.30607
# INFO:tensorflow:loss = 0.4805194, step = 500 (43.364 sec)
# INFO:tensorflow:global_step/sec: 2.33878
# INFO:tensorflow:loss = 0.9228488, step = 600 (42.757 sec)
# INFO:tensorflow:global_step/sec: 2.28596
# INFO:tensorflow:loss = 1.0663389, step = 700 (43.745 sec)
# INFO:tensorflow:global_step/sec: 2.28422
# INFO:tensorflow:loss = 0.678206, step = 800 (43.780 sec)
# INFO:tensorflow:global_step/sec: 2.2884
# INFO:tensorflow:loss = 0.393523, step = 900 (43.698 sec)
# INFO:tensorflow:global_step/sec: 2.28316
# INFO:tensorflow:loss = 0.7616402, step = 1000 (43.799 sec)
# INFO:tensorflow:global_step/sec: 2.27804
# INFO:tensorflow:loss = 0.33070126, step = 1100 (43.897 sec)
# INFO:tensorflow:global_step/sec: 2.31589
# INFO:tensorflow:loss = 0.84386766, step = 1200 (43.180 sec)
# INFO:tensorflow:global_step/sec: 2.33501
# INFO:tensorflow:loss = 0.7812457, step = 1300 (42.827 sec)
# INFO:tensorflow:Saving checkpoints for 1356 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.53259957.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-16:01:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-1356
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-16:01:35
# INFO:tensorflow:Saving dict for global step 1356: accuracy = 0.785625, global_step = 1356, loss = 0.6062829
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-1356
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1357 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.31655478, step = 1356
# INFO:tensorflow:global_step/sec: 2.20506
# INFO:tensorflow:loss = 0.83761925, step = 1456 (45.352 sec)
# INFO:tensorflow:global_step/sec: 2.28663
# INFO:tensorflow:loss = 0.72907054, step = 1556 (43.732 sec)
# INFO:tensorflow:global_step/sec: 2.33749
# INFO:tensorflow:loss = 0.25135994, step = 1656 (42.781 sec)
# INFO:tensorflow:global_step/sec: 2.29447
# INFO:tensorflow:loss = 0.33645058, step = 1756 (43.583 sec)
# INFO:tensorflow:global_step/sec: 2.28955
# INFO:tensorflow:loss = 0.53130853, step = 1856 (43.677 sec)
# INFO:tensorflow:global_step/sec: 2.26786
# INFO:tensorflow:loss = 0.36470324, step = 1956 (44.094 sec)
# INFO:tensorflow:global_step/sec: 2.28219
# INFO:tensorflow:loss = 0.2356232, step = 2056 (43.818 sec)
# INFO:tensorflow:global_step/sec: 2.27923
# INFO:tensorflow:loss = 0.32777044, step = 2156 (43.874 sec)
# INFO:tensorflow:global_step/sec: 2.2718
# INFO:tensorflow:loss = 0.2978651, step = 2256 (44.018 sec)
# INFO:tensorflow:global_step/sec: 2.30791
# INFO:tensorflow:loss = 0.4203448, step = 2356 (43.330 sec)
# INFO:tensorflow:global_step/sec: 2.25853
# INFO:tensorflow:loss = 0.3064698, step = 2456 (44.276 sec)
# INFO:tensorflow:global_step/sec: 2.30047
# INFO:tensorflow:loss = 0.47259688, step = 2556 (43.470 sec)
# INFO:tensorflow:global_step/sec: 2.31847
# INFO:tensorflow:loss = 0.23298109, step = 2656 (43.132 sec)
# INFO:tensorflow:Saving checkpoints for 2702 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5851722.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-16:11:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-2702
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-16:12:05
# INFO:tensorflow:Saving dict for global step 2702: accuracy = 0.82625, global_step = 2702, loss = 0.52718335
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-2702
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2703 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.4305269, step = 2702
# INFO:tensorflow:global_step/sec: 2.25272
# INFO:tensorflow:loss = 0.6343167, step = 2802 (44.392 sec)
# INFO:tensorflow:global_step/sec: 2.29899
# INFO:tensorflow:loss = 0.45018548, step = 2902 (43.498 sec)
# INFO:tensorflow:global_step/sec: 2.2505
# INFO:tensorflow:loss = 0.929176, step = 3002 (44.434 sec)
# INFO:tensorflow:global_step/sec: 2.27522
# INFO:tensorflow:loss = 0.2454274, step = 3102 (43.952 sec)
# INFO:tensorflow:global_step/sec: 2.25012
# INFO:tensorflow:loss = 0.5983105, step = 3202 (44.443 sec)
# INFO:tensorflow:global_step/sec: 2.26733
# INFO:tensorflow:loss = 0.4194876, step = 3302 (44.104 sec)
# INFO:tensorflow:global_step/sec: 2.30035
# INFO:tensorflow:loss = 0.41727203, step = 3602 (43.472 sec)
# INFO:tensorflow:global_step/sec: 2.2804
# INFO:tensorflow:loss = 0.24970691, step = 3702 (43.851 sec)
# INFO:tensorflow:global_step/sec: 2.34163
# INFO:tensorflow:loss = 0.22017482, step = 3802 (42.706 sec)
# INFO:tensorflow:global_step/sec: 2.27976
# INFO:tensorflow:loss = 0.3615613, step = 3902 (43.864 sec)
# INFO:tensorflow:global_step/sec: 2.31562
# INFO:tensorflow:loss = 0.39242703, step = 4002 (43.186 sec)
# INFO:tensorflow:Saving checkpoints for 4048 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3234238.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-16:22:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-4048
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-16:22:35
# INFO:tensorflow:Saving dict for global step 4048: accuracy = 0.8428125, global_step = 4048, loss = 0.4484929
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-4048
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4049 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.3538958, step = 4048
# INFO:tensorflow:global_step/sec: 2.24019
# INFO:tensorflow:loss = 0.25584173, step = 4148 (44.640 sec)
# INFO:tensorflow:global_step/sec: 2.31988
# INFO:tensorflow:loss = 0.33781183, step = 4248 (43.106 sec)
# INFO:tensorflow:global_step/sec: 2.29522
# INFO:tensorflow:loss = 0.57353055, step = 4348 (43.568 sec)
# INFO:tensorflow:global_step/sec: 2.32933
# INFO:tensorflow:loss = 0.5223558, step = 4448 (42.930 sec)
# INFO:tensorflow:global_step/sec: 2.27791
# INFO:tensorflow:loss = 0.20820959, step = 4548 (43.900 sec)
# INFO:tensorflow:global_step/sec: 2.28074
# INFO:tensorflow:loss = 0.26081347, step = 4648 (43.847 sec)
# INFO:tensorflow:global_step/sec: 2.30533
# INFO:tensorflow:loss = 0.49274227, step = 4748 (43.376 sec)
# INFO:tensorflow:global_step/sec: 2.30057
# INFO:tensorflow:loss = 0.39547366, step = 4848 (43.468 sec)
# INFO:tensorflow:global_step/sec: 2.30482
# INFO:tensorflow:loss = 0.659672, step = 4948 (43.388 sec)
# INFO:tensorflow:global_step/sec: 2.27713
# INFO:tensorflow:loss = 0.25430942, step = 5048 (43.915 sec)
# INFO:tensorflow:global_step/sec: 2.29594
# INFO:tensorflow:loss = 0.546931, step = 5148 (43.555 sec)
# INFO:tensorflow:global_step/sec: 2.28583
# INFO:tensorflow:loss = 0.4774289, step = 5248 (43.747 sec)
# INFO:tensorflow:global_step/sec: 2.31894
# INFO:tensorflow:loss = 0.45132038, step = 5348 (43.123 sec)
# INFO:tensorflow:Saving checkpoints for 5398 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4175849.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-16:32:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-5398
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-16:33:04
# INFO:tensorflow:Saving dict for global step 5398: accuracy = 0.851875, global_step = 5398, loss = 0.44229102
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-5398
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5399 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.26646703, step = 5398
# INFO:tensorflow:global_step/sec: 2.24956
# INFO:tensorflow:loss = 0.24718592, step = 5498 (44.454 sec)
# INFO:tensorflow:global_step/sec: 2.32381
# INFO:tensorflow:loss = 0.8767848, step = 5598 (43.033 sec)
# INFO:tensorflow:global_step/sec: 2.26462
# INFO:tensorflow:loss = 0.40393406, step = 5698 (44.157 sec)
# INFO:tensorflow:global_step/sec: 2.32094
# INFO:tensorflow:loss = 0.494307, step = 5798 (43.087 sec)
# INFO:tensorflow:global_step/sec: 2.32889
# INFO:tensorflow:loss = 0.21544093, step = 5898 (42.938 sec)
# INFO:tensorflow:global_step/sec: 2.29097
# INFO:tensorflow:loss = 0.2911585, step = 5998 (43.649 sec)
# INFO:tensorflow:global_step/sec: 2.26459
# INFO:tensorflow:loss = 0.34449202, step = 6098 (44.159 sec)
# INFO:tensorflow:global_step/sec: 2.28731
# INFO:tensorflow:loss = 0.4128063, step = 6198 (43.720 sec)
# INFO:tensorflow:global_step/sec: 2.26032
# INFO:tensorflow:loss = 0.30048704, step = 6298 (44.241 sec)
# INFO:tensorflow:global_step/sec: 2.2867
# INFO:tensorflow:loss = 0.2683735, step = 6398 (43.731 sec)
# INFO:tensorflow:global_step/sec: 2.34061
# INFO:tensorflow:loss = 0.61256444, step = 6498 (42.724 sec)
# INFO:tensorflow:global_step/sec: 2.28194
# INFO:tensorflow:loss = 0.25132963, step = 6598 (43.822 sec)
# INFO:tensorflow:global_step/sec: 2.33397
# INFO:tensorflow:loss = 0.55878633, step = 6698 (42.845 sec)
# INFO:tensorflow:Saving checkpoints for 6751 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.45796818.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-16:43:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-6751
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-16:43:34
# INFO:tensorflow:Saving dict for global step 6751: accuracy = 0.8365625, global_step = 6751, loss = 0.45584878
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-6751
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6752 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.32400167, step = 6751
# INFO:tensorflow:global_step/sec: 2.24051
# INFO:tensorflow:loss = 0.5518963, step = 6851 (44.634 sec)
# INFO:tensorflow:global_step/sec: 2.29841
# INFO:tensorflow:loss = 0.7442437, step = 6951 (43.509 sec)
# INFO:tensorflow:global_step/sec: 2.29372
# INFO:tensorflow:loss = 0.07726069, step = 7051 (43.597 sec)
# INFO:tensorflow:global_step/sec: 2.32257
# INFO:tensorflow:loss = 0.2810201, step = 7151 (43.056 sec)
# INFO:tensorflow:global_step/sec: 2.28771
# INFO:tensorflow:loss = 0.4292127, step = 7251 (43.712 sec)
# INFO:tensorflow:global_step/sec: 2.28344
# INFO:tensorflow:loss = 0.42723933, step = 7351 (43.793 sec)
# INFO:tensorflow:global_step/sec: 2.28123
# INFO:tensorflow:loss = 0.2291981, step = 7451 (43.836 sec)
# INFO:tensorflow:global_step/sec: 2.31318
# INFO:tensorflow:loss = 0.32452595, step = 7551 (43.231 sec)
# INFO:tensorflow:global_step/sec: 2.30479
# INFO:tensorflow:loss = 0.49235055, step = 7651 (43.388 sec)
# INFO:tensorflow:global_step/sec: 2.29077
# INFO:tensorflow:loss = 0.34596077, step = 7751 (43.653 sec)
# INFO:tensorflow:global_step/sec: 2.31361
# INFO:tensorflow:loss = 0.6045236, step = 7851 (43.222 sec)
# INFO:tensorflow:global_step/sec: 2.31367
# INFO:tensorflow:loss = 0.31898737, step = 7951 (43.222 sec)
# INFO:tensorflow:global_step/sec: 2.29758
# INFO:tensorflow:loss = 0.5241441, step = 8051 (43.524 sec)
# INFO:tensorflow:Saving checkpoints for 8101 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0271357.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-16:53:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-8101
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-16:54:03
# INFO:tensorflow:Saving dict for global step 8101: accuracy = 0.8403125, global_step = 8101, loss = 0.44687384
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-8101
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8102 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.26244488, step = 8101
# INFO:tensorflow:global_step/sec: 2.20029
# INFO:tensorflow:loss = 0.2696262, step = 8201 (45.450 sec)
# INFO:tensorflow:global_step/sec: 2.33144
# INFO:tensorflow:loss = 0.40155965, step = 8301 (42.891 sec)
# INFO:tensorflow:global_step/sec: 2.28755
# INFO:tensorflow:loss = 0.2436091, step = 8401 (43.715 sec)
# INFO:tensorflow:global_step/sec: 2.31578
# INFO:tensorflow:loss = 0.27898294, step = 8501 (43.182 sec)
# INFO:tensorflow:global_step/sec: 2.30452
# INFO:tensorflow:loss = 0.45979178, step = 8601 (43.393 sec)
# INFO:tensorflow:global_step/sec: 2.28449
# INFO:tensorflow:loss = 0.49916804, step = 8701 (43.774 sec)
# INFO:tensorflow:global_step/sec: 2.32794
# INFO:tensorflow:loss = 0.3619347, step = 8801 (42.956 sec)
# INFO:tensorflow:global_step/sec: 2.26659
# INFO:tensorflow:loss = 0.488311, step = 8901 (44.119 sec)
# INFO:tensorflow:global_step/sec: 2.27154
# INFO:tensorflow:loss = 0.48064113, step = 9001 (44.023 sec)
# INFO:tensorflow:global_step/sec: 2.27742
# INFO:tensorflow:loss = 0.24772018, step = 9101 (43.909 sec)
# INFO:tensorflow:global_step/sec: 2.27589
# INFO:tensorflow:loss = 0.85705626, step = 9201 (43.940 sec)
# INFO:tensorflow:global_step/sec: 2.29762
# INFO:tensorflow:loss = 0.2440176, step = 9301 (43.523 sec)
# INFO:tensorflow:global_step/sec: 2.27663
# INFO:tensorflow:loss = 0.26356506, step = 9401 (43.924 sec)
# INFO:tensorflow:Saving checkpoints for 9447 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4738794.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-17:04:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-9447
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-17:04:33
# INFO:tensorflow:Saving dict for global step 9447: accuracy = 0.8475, global_step = 9447, loss = 0.43786296
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-9447
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9448 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.25223014, step = 9447
# INFO:tensorflow:global_step/sec: 2.22783
# INFO:tensorflow:loss = 0.46226132, step = 9547 (44.888 sec)
# INFO:tensorflow:global_step/sec: 2.30665
# INFO:tensorflow:loss = 0.4789976, step = 9647 (43.353 sec)
# INFO:tensorflow:global_step/sec: 2.32001
# INFO:tensorflow:loss = 0.7100369, step = 9747 (43.103 sec)
# INFO:tensorflow:global_step/sec: 2.30507
# INFO:tensorflow:loss = 0.28845334, step = 9847 (43.382 sec)
# INFO:tensorflow:global_step/sec: 2.29262
# INFO:tensorflow:loss = 0.23822454, step = 9947 (43.618 sec)
# INFO:tensorflow:global_step/sec: 2.29322
# INFO:tensorflow:loss = 0.36976087, step = 10047 (43.607 sec)
# INFO:tensorflow:global_step/sec: 2.29352
# INFO:tensorflow:loss = 0.38110507, step = 10147 (43.602 sec)
# INFO:tensorflow:global_step/sec: 2.29679
# INFO:tensorflow:loss = 0.23622629, step = 10247 (43.539 sec)
# INFO:tensorflow:global_step/sec: 2.27555
# INFO:tensorflow:loss = 0.6062541, step = 10347 (43.945 sec)
# INFO:tensorflow:global_step/sec: 2.30647
# INFO:tensorflow:loss = 0.46787894, step = 10447 (43.356 sec)
# INFO:tensorflow:global_step/sec: 2.30432
# INFO:tensorflow:loss = 0.6081226, step = 10547 (43.397 sec)
# INFO:tensorflow:global_step/sec: 2.30362
# INFO:tensorflow:loss = 0.34627014, step = 10647 (43.410 sec)
# INFO:tensorflow:global_step/sec: 2.28707
# INFO:tensorflow:loss = 0.28289598, step = 10747 (43.724 sec)
# INFO:tensorflow:Saving checkpoints for 10798 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.34267604.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-17:14:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-10798
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-11-17:15:03
# INFO:tensorflow:Saving dict for global step 10798: accuracy = 0.8290625, global_step = 10798, loss = 0.4974388
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/rmspropoffnet101/model.ckpt-10798
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10799 into models/rmspropoffnet101/model.ckpt.
# INFO:tensorflow:loss = 0.2890277, step = 10798
# INFO:tensorflow:global_step/sec: 2.26235
# INFO:tensorflow:loss = 0.3426069, step = 10898 (44.203 sec)
# INFO:tensorflow:global_step/sec: 2.28038
# INFO:tensorflow:loss = 0.37383932, step = 10998 (43.852 sec)
# INFO:tensorflow:global_step/sec: 2.30182
# INFO:tensorflow:loss = 0.36577457, step = 11098 (43.444 sec)
# INFO:tensorflow:global_step/sec: 2.26964
# INFO:tensorflow:loss = 0.5591593, step = 11198 (44.060 sec)
# INFO:tensorflow:global_step/sec: 2.3328
# INFO:tensorflow:loss = 0.16129631, step = 11298 (42.867 sec)
# INFO:tensorflow:global_step/sec: 2.33141
# INFO:tensorflow:loss = 0.49693695, step = 11398 (42.893 sec)
# INFO:tensorflow:global_step/sec: 2.29086
# INFO:tensorflow:loss = 0.17559527, step = 11498 (43.651 sec)
# INFO:tensorflow:global_step/sec: 2.30777
# INFO:tensorflow:loss = 0.47888613, step = 11598 (43.332 sec)
# INFO:tensorflow:global_step/sec: 2.2777
# INFO:tensorflow:loss = 0.38743597, step = 11698 (43.903 sec)
# INFO:tensorflow:global_step/sec: 2.31934
# INFO:tensorflow:loss = 0.46563488, step = 11798 (43.116 sec)
# INFO:tensorflow:global_step/sec: 2.29232
# INFO:tensorflow:loss = 0.32815382, step = 11898 (43.624 sec)

# %%
# estimator.evaluate(input_fn=lambda:tf.data.Dataset.from_tensor_slices(testing_data).batch(3).take(1))

# %%
# tuple(estimator.predict(input_fn=lambda:tf.data.Dataset.from_tensor_slices(testing_data).batch(3).take(1)))

# %%
# estimator.train(input_fn=training_dataset, steps=1)
