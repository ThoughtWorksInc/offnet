# %%
import mmh3

# %%
import functools

# %%
import iteration_utilities

# %%
import random

# %%
import numpy as np

# %%
import math

# %%
import tensorflow as tf

# %%
from tensorflow.python import debug as tf_debug

# %%
from enum import IntEnum

# %%
print("TensorFlow version: {}".format(tf.VERSION))
# Out:
# TensorFlow version: 1.8.0

# %%
# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
training_data, testing_data = tf.keras.datasets.fashion_mnist.load_data()

# %%
number_of_classes = int(np.max(testing_data[1])) + 1
number_of_input_channels = 1

# %%
number_of_experts = 1

# %%
number_of_hidden_layers = 20

# %%
number_of_features_per_layer = 32

# %%
paddings = (0, 0), (2, 2), (2, 2)

# %%
random_seed = number_of_hidden_layers

# %%
def offset_initializer():
    return tf.random_normal_initializer(stddev=1.0)
#     return tf.random_uniform_initializer(minval=-3.0, maxval=3.0)

# %%
def grid_sample(images, offset_x, offset_y):
    tf.assert_rank(images, 4)
    tf.assert_rank(offset_x, 4)
    tf.assert_rank(offset_y, 4)
    image_shape = tf.shape(images)
    current_batch_size = image_shape[0]
    width = image_shape[1]
    height = image_shape[2]
    number_of_features = image_shape[3]
    
    def check_width(tensor):
        if (tf.test.is_gpu_available()):
            return tensor
        else:
            return tf.maximum(tf.minimum(tensor, width - 1), 0)
    
    def check_height(tensor):
        if (tf.test.is_gpu_available()):
            return tensor
        else:
            return tf.maximum(tf.minimum(tensor, height - 1), 0)
    
    offset_left = tf.floor(offset_x)
    offset_top = tf.floor(offset_y)
    tf.assert_equal(tf.shape(offset_left), image_shape)
    tf.assert_equal(tf.shape(offset_top), image_shape)

    
    eps = 1e-7

    factor_right = offset_x - offset_left + eps
    factor_left = 1.0 + 2.0 * eps - factor_right
    factor_bottom = offset_y - offset_top + eps
    factor_top = 1.0 + 2.0 * eps - factor_bottom
    
    image_index, x_index, y_index, feature_index = tf.meshgrid(
        tf.range(current_batch_size, dtype=tf.int32),
        tf.range(width, dtype=tf.int32),
        tf.range(height, dtype=tf.int32),
        tf.range(number_of_features, dtype=tf.int32),
        indexing='ij',
    )

    left_index = check_width(x_index + tf.cast(offset_left, tf.int32))
    top_index = check_height(y_index + tf.cast(offset_top, tf.int32))

    right_index = left_index + 1
    bottom_index = top_index + 1
    
    tf.assert_rank(left_index, 4)
    tf.assert_rank(right_index, 4)
    tf.assert_rank(bottom_index, 4)
    tf.assert_rank(top_index, 4)
    
    images_top_left = tf.gather_nd(images, tf.stack((image_index, left_index, top_index, feature_index), axis=4))
    images_top_right = tf.gather_nd(images, tf.stack((image_index, right_index, top_index, feature_index), axis=4))
    images_bottom_left = tf.gather_nd(images, tf.stack((image_index, left_index, bottom_index, feature_index), axis=4))
    images_bottom_right = tf.gather_nd(images, tf.stack((image_index, right_index, bottom_index, feature_index), axis=4))

    tf.assert_rank(images_top_left, 4)
    tf.assert_rank(images_top_right, 4)
    tf.assert_rank(images_bottom_left, 4)
    tf.assert_rank(images_bottom_right, 4)

    lerp_top = factor_left * images_top_left + factor_right * images_top_right
    lerp_bottom = factor_left * images_bottom_left + factor_right * images_bottom_right
    output = factor_top * lerp_top + factor_bottom * lerp_bottom
    tf.assert_rank(output, 4)
    return output

# %%
def offnet(images, number_of_features, number_of_experts=None, name=None):
    with tf.variable_scope(name, default_name="offnet"):
        input_shape = images.shape
        if number_of_experts is None:
            number_of_experts = int(input_shape[0])
        number_of_input_features = int(input_shape[4])
        score_weight = tf.get_variable(
            name="score_weight",
            initializer=tf.random_normal_initializer(stddev=tf.sqrt(1.0 / number_of_input_features)),
            dtype=tf.float32,
            shape=(number_of_experts, number_of_input_features, number_of_features)
        )
        offset_x_weight = tf.get_variable(
            name="offset_x_weight",
            initializer=tf.random_normal_initializer(stddev=tf.sqrt(1.0 / number_of_input_features)),
            dtype=tf.float32,
            shape=(number_of_experts, number_of_input_features, number_of_features)
        )
        offset_y_weight = tf.get_variable(
            name="offset_y_weight",
            initializer=tf.random_normal_initializer(stddev=tf.sqrt(1.0 / number_of_input_features)),
            dtype=tf.float32,
            shape=(number_of_experts, number_of_input_features, number_of_features)
        )
        offset_x_bias = tf.get_variable(
            name="offset_x_bias",
            initializer=offset_initializer(),
            dtype=tf.float32,
            shape=(number_of_experts, 1, number_of_features),
        )
        offset_y_bias = tf.get_variable(
            name="offset_y_bias",
            initializer=offset_initializer(),
            dtype=tf.float32,
            shape=(number_of_experts, 1,  number_of_features),
        )
#         def scale_initializer():
#             return tf.sqrt(weight_scale / number_of_input_features)
#         score_scale = tf.get_variable(
#             name="score_scale",
#             initializer=scale_initializer(),
#             dtype=tf.float32
#         )
#         offset_x_scale = tf.get_variable(
#             name="offset_x_scale",
#             initializer=scale_initializer(),
#             dtype=tf.float32
#         )
#         offset_y_scale = tf.get_variable(
#             name="offset_y_scale",
#             initializer=scale_initializer(),
#             dtype=tf.float32
#         )
        
        dynamic_image_shape = tf.shape(images)
        images_3d = tf.reshape(
            images,
            (
                number_of_experts,
                dynamic_image_shape[1] * dynamic_image_shape[2] * dynamic_image_shape[3],
                number_of_input_features
            )
        )
        def images_xw_plus_b(w, b):
            tf.matmul(images_3d, w) + b
        
        def to_4d(images):
            tf.assert_equal(tf.shape(images), (number_of_experts, dynamic_image_shape[1] * dynamic_image_shape[2] * dynamic_image_shape[3], number_of_features))
            return tf.reshape(
                images,
                (
                    number_of_experts * dynamic_image_shape[1],
                    dynamic_image_shape[2],
                    dynamic_image_shape[3],
                    number_of_features
                )
            )
        return tf.reshape(
            grid_sample(
                to_4d(tf.matmul(images_3d, score_weight)),
                to_4d(tf.matmul(images_3d, offset_x_weight) + offset_x_bias),
                to_4d(tf.matmul(images_3d, offset_y_weight) + offset_y_bias)
            ),
            (
                number_of_experts,
                dynamic_image_shape[1],
                dynamic_image_shape[2],
                dynamic_image_shape[3],
                number_of_features
            )
        )

# %%
number_of_horizontal_samples = 3
number_of_vertical_samples = 3

# %%
def model_fn(features, labels, mode, params, config):
    random.seed(number_of_hidden_layers)
    padded_input = tf.expand_dims(
        tf.expand_dims(
            tf.pad(tf.cast(features, tf.float32) / 255.0 - 0.5, paddings),
            axis=0
        ),
        axis=4
    )
    width = int(padded_input.shape[2])
    height = int(padded_input.shape[3])
    
    layers = functools.reduce(
        lambda features, i: tf.layers.batch_normalization(
            offnet(features, number_of_features_per_layer, 1),
            training=mode is tf.estimator.ModeKeys.TRAIN
        ),
        range(number_of_hidden_layers),
        padded_input
    )
    score_layer = offnet(layers, number_of_classes, number_of_experts)
    scores = tf.reduce_mean(
        tf.reduce_mean(
            score_layer,
            axis=0
        )[
            :,
            int(width / (number_of_horizontal_samples + 1)):int(width * number_of_horizontal_samples / (number_of_horizontal_samples + 1)):int(width / (number_of_horizontal_samples + 1)),
            int(height / (number_of_horizontal_samples + 1)):int(height * number_of_horizontal_samples / (number_of_horizontal_samples + 1)):int(height / (number_of_horizontal_samples + 1)),
            :
        ],
        axis=(1, 2)
    )

    probabilities = tf.nn.softmax(logits=scores)
    predicted_classes = tf.argmax(scores, 1)
    predictions = {
        'probabilities' : probabilities,
        'scores': scores,
        'class': predicted_classes,
    }

    optimizer = tf.train.AdamOptimizer(epsilon=0.1)
    if labels is None:
        return tf.estimator.EstimatorSpec(
            mode=mode,
            predictions=predictions,
        )
    else:
        loss = tf.losses.softmax_cross_entropy(logits=scores, onehot_labels=tf.one_hot(labels, number_of_classes))
        eval_metric_ops = {
            'accuracy': tf.metrics.accuracy(labels=labels, predictions=predicted_classes)
        }
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            return tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=predictions,
                loss=loss,
                train_op=optimizer.minimize(loss, global_step=tf.train.get_global_step()),
                eval_metric_ops=eval_metric_ops,
            )

# %%
run_config = tf.estimator.RunConfig(
    model_dir=f"models/simpleoffnet{number_of_features_per_layer}x{number_of_hidden_layers}",
    session_config=tf.ConfigProto(
        gpu_options=tf.GPUOptions(
            allow_growth=True,
        ),
        graph_options=tf.GraphOptions(
            optimizer_options=tf.OptimizerOptions(
                global_jit_level=tf.OptimizerOptions.ON_2,
                do_function_inlining=True,
                do_constant_folding=True,
                do_common_subexpression_elimination=True,
            ),
        )
    )
)

# %%
estimator = tf.estimator.Estimator(model_fn, config=run_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'models/simpleoffnet', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   allow_growth: true
# }
# graph_options {
#   optimizer_options {
#     do_common_subexpression_elimination: true
#     do_constant_folding: true
#     do_function_inlining: true
#     global_jit_level: ON_2
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8967200da0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x7f89672031e0>) includes params argument, but params are not passed to Estimator.

# %%
batch_size = 32

# %%
def training_dataset():
    return tf.data.Dataset.from_tensor_slices(training_data).shuffle(1000).batch(batch_size)

# %%
def testing_dataset():
    return tf.data.Dataset.from_tensor_slices(testing_data).batch(batch_size)

# %%
# hook = tf_debug.TensorBoardDebugHook("localhost:6064")
# estimator.train(training_dataset,hooks=[hook])

# %%
tf.estimator.train_and_evaluate(
    estimator,
    train_spec=tf.estimator.TrainSpec(training_dataset),
    eval_spec=tf.estimator.EvalSpec(testing_dataset, throttle_secs=1800)
)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 1800 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 2.6052835, step = 0
# INFO:tensorflow:global_step/sec: 0.990624
# INFO:tensorflow:loss = 1.9547856, step = 100 (100.947 sec)
# INFO:tensorflow:global_step/sec: 1.06994
# INFO:tensorflow:loss = 1.2845535, step = 200 (93.463 sec)
# INFO:tensorflow:global_step/sec: 1.06883
# INFO:tensorflow:loss = 1.1193528, step = 300 (93.562 sec)
# INFO:tensorflow:global_step/sec: 1.07109
# INFO:tensorflow:loss = 0.9697079, step = 400 (93.362 sec)
# INFO:tensorflow:global_step/sec: 1.06954
# INFO:tensorflow:loss = 1.0844632, step = 500 (93.498 sec)
# INFO:tensorflow:global_step/sec: 1.0683
# INFO:tensorflow:loss = 0.8384253, step = 600 (93.607 sec)
# INFO:tensorflow:Saving checkpoints for 634 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05422
# INFO:tensorflow:loss = 0.802345, step = 700 (94.857 sec)
# INFO:tensorflow:global_step/sec: 1.07034
# INFO:tensorflow:loss = 0.7052188, step = 800 (93.429 sec)
# INFO:tensorflow:global_step/sec: 1.06991
# INFO:tensorflow:loss = 0.92152286, step = 1000 (93.467 sec)
# INFO:tensorflow:global_step/sec: 1.06914
# INFO:tensorflow:loss = 0.7494948, step = 1100 (93.532 sec)
# INFO:tensorflow:global_step/sec: 1.06887
# INFO:tensorflow:loss = 0.55295974, step = 1200 (93.557 sec)
# INFO:tensorflow:Saving checkpoints for 1275 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05449
# INFO:tensorflow:loss = 0.71283525, step = 1300 (94.833 sec)
# INFO:tensorflow:global_step/sec: 1.06847
# INFO:tensorflow:loss = 0.8793566, step = 1400 (93.592 sec)
# INFO:tensorflow:global_step/sec: 1.07055
# INFO:tensorflow:loss = 0.41288018, step = 1500 (93.409 sec)
# INFO:tensorflow:global_step/sec: 1.06906
# INFO:tensorflow:loss = 0.59553325, step = 1600 (93.541 sec)
# INFO:tensorflow:global_step/sec: 1.06898
# INFO:tensorflow:loss = 0.63301545, step = 1700 (93.547 sec)
# INFO:tensorflow:global_step/sec: 1.06784
# INFO:tensorflow:loss = 0.62993616, step = 1800 (93.647 sec)
# INFO:tensorflow:Saving checkpoints for 1875 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7185189.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-03:37:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-1875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-03:38:56
# INFO:tensorflow:Saving dict for global step 1875: accuracy = 0.7734375, global_step = 1875, loss = 0.64018285
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-1875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1876 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.53516614, step = 1875
# INFO:tensorflow:global_step/sec: 0.991511
# INFO:tensorflow:loss = 0.5470817, step = 1975 (100.857 sec)
# INFO:tensorflow:global_step/sec: 1.06921
# INFO:tensorflow:loss = 0.51820374, step = 2075 (93.527 sec)
# INFO:tensorflow:global_step/sec: 1.06807
# INFO:tensorflow:loss = 0.41519982, step = 2175 (93.627 sec)
# INFO:tensorflow:global_step/sec: 1.06824
# INFO:tensorflow:loss = 0.6750046, step = 2275 (93.612 sec)
# INFO:tensorflow:global_step/sec: 1.06852
# INFO:tensorflow:loss = 0.49348706, step = 2375 (93.587 sec)
# INFO:tensorflow:global_step/sec: 1.06947
# INFO:tensorflow:loss = 0.60781896, step = 2475 (93.504 sec)
# INFO:tensorflow:Saving checkpoints for 2508 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05281
# INFO:tensorflow:loss = 0.678751, step = 2575 (94.983 sec)
# INFO:tensorflow:global_step/sec: 1.06935
# INFO:tensorflow:loss = 0.45322752, step = 2675 (93.515 sec)
# INFO:tensorflow:global_step/sec: 1.06943
# INFO:tensorflow:loss = 0.5397382, step = 2775 (93.507 sec)
# INFO:tensorflow:global_step/sec: 1.06738
# INFO:tensorflow:loss = 0.85803694, step = 2875 (93.688 sec)
# INFO:tensorflow:global_step/sec: 1.06818
# INFO:tensorflow:loss = 0.37428582, step = 2975 (93.617 sec)
# INFO:tensorflow:global_step/sec: 1.06981
# INFO:tensorflow:loss = 0.457648, step = 3075 (93.474 sec)
# INFO:tensorflow:Saving checkpoints for 3148 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05343
# INFO:tensorflow:loss = 0.43587738, step = 3175 (94.928 sec)
# INFO:tensorflow:global_step/sec: 1.06748
# INFO:tensorflow:loss = 0.6166188, step = 3275 (93.678 sec)
# INFO:tensorflow:global_step/sec: 1.06899
# INFO:tensorflow:loss = 0.4773423, step = 3375 (93.546 sec)
# INFO:tensorflow:global_step/sec: 1.06834
# INFO:tensorflow:loss = 0.22737205, step = 3475 (93.604 sec)
# INFO:tensorflow:global_step/sec: 1.06872
# INFO:tensorflow:loss = 0.58088195, step = 3575 (93.570 sec)
# INFO:tensorflow:global_step/sec: 1.06578
# INFO:tensorflow:loss = 0.66908705, step = 3675 (93.828 sec)
# INFO:tensorflow:Saving checkpoints for 3750 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.34470838.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-04:09:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-3750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-04:10:50
# INFO:tensorflow:Saving dict for global step 3750: accuracy = 0.805, global_step = 3750, loss = 0.532502
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-3750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3751 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.53049845, step = 3750
# INFO:tensorflow:global_step/sec: 0.993289
# INFO:tensorflow:loss = 0.49995586, step = 3850 (100.677 sec)
# INFO:tensorflow:global_step/sec: 1.06924
# INFO:tensorflow:loss = 0.2812074, step = 3950 (93.524 sec)
# INFO:tensorflow:global_step/sec: 1.06962
# INFO:tensorflow:loss = 0.19452968, step = 4050 (93.491 sec)
# INFO:tensorflow:global_step/sec: 1.07032
# INFO:tensorflow:loss = 0.7305477, step = 4150 (93.430 sec)
# INFO:tensorflow:global_step/sec: 1.07052
# INFO:tensorflow:loss = 0.5135876, step = 4250 (93.412 sec)
# INFO:tensorflow:global_step/sec: 1.07004
# INFO:tensorflow:loss = 0.47077706, step = 4350 (93.455 sec)
# INFO:tensorflow:Saving checkpoints for 4384 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05691
# INFO:tensorflow:loss = 0.3310246, step = 4450 (94.615 sec)
# INFO:tensorflow:global_step/sec: 1.07017
# INFO:tensorflow:loss = 0.40816313, step = 4550 (93.443 sec)
# INFO:tensorflow:global_step/sec: 1.06926
# INFO:tensorflow:loss = 0.5312705, step = 4650 (93.523 sec)
# INFO:tensorflow:global_step/sec: 1.06939
# INFO:tensorflow:loss = 0.3970396, step = 4750 (93.511 sec)
# INFO:tensorflow:global_step/sec: 1.06978
# INFO:tensorflow:loss = 0.6966105, step = 4950 (93.477 sec)
# INFO:tensorflow:Saving checkpoints for 5025 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05364
# INFO:tensorflow:loss = 0.47399297, step = 5050 (94.909 sec)
# INFO:tensorflow:global_step/sec: 1.06818
# INFO:tensorflow:loss = 0.4388981, step = 5150 (93.617 sec)
# INFO:tensorflow:global_step/sec: 1.06985
# INFO:tensorflow:loss = 0.2767309, step = 5250 (93.471 sec)
# INFO:tensorflow:global_step/sec: 1.06987
# INFO:tensorflow:loss = 0.41633233, step = 5350 (93.469 sec)
# INFO:tensorflow:global_step/sec: 1.07059
# INFO:tensorflow:loss = 0.33984685, step = 5450 (93.406 sec)
# INFO:tensorflow:global_step/sec: 1.06888
# INFO:tensorflow:loss = 0.3096411, step = 5550 (93.556 sec)
# INFO:tensorflow:Saving checkpoints for 5625 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.32464337.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-04:41:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-5625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-04:42:37
# INFO:tensorflow:Saving dict for global step 5625: accuracy = 0.82625, global_step = 5625, loss = 0.49988815
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-5625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5626 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.45327392, step = 5625
# INFO:tensorflow:global_step/sec: 0.991514
# INFO:tensorflow:loss = 0.59294635, step = 5725 (100.856 sec)
# INFO:tensorflow:global_step/sec: 1.06787
# INFO:tensorflow:loss = 0.61603916, step = 5825 (93.645 sec)
# INFO:tensorflow:global_step/sec: 1.07104
# INFO:tensorflow:loss = 0.4204728, step = 5925 (93.367 sec)
# INFO:tensorflow:global_step/sec: 1.06804
# INFO:tensorflow:loss = 0.21479951, step = 6025 (93.630 sec)
# INFO:tensorflow:global_step/sec: 1.06979
# INFO:tensorflow:loss = 0.4527013, step = 6125 (93.476 sec)
# INFO:tensorflow:global_step/sec: 1.06956
# INFO:tensorflow:loss = 0.43447274, step = 6225 (93.497 sec)
# INFO:tensorflow:Saving checkpoints for 6259 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05422
# INFO:tensorflow:loss = 0.5709645, step = 6325 (94.856 sec)
# INFO:tensorflow:global_step/sec: 1.06978
# INFO:tensorflow:loss = 0.4095052, step = 6425 (93.478 sec)
# INFO:tensorflow:global_step/sec: 1.07037
# INFO:tensorflow:loss = 0.23292989, step = 6525 (93.425 sec)
# INFO:tensorflow:global_step/sec: 1.07031
# INFO:tensorflow:loss = 0.65130186, step = 6625 (93.431 sec)
# INFO:tensorflow:global_step/sec: 1.06929
# INFO:tensorflow:loss = 0.34954774, step = 6725 (93.520 sec)
# INFO:tensorflow:global_step/sec: 1.06963
# INFO:tensorflow:loss = 0.3413309, step = 6825 (93.491 sec)
# INFO:tensorflow:Saving checkpoints for 6900 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05493
# INFO:tensorflow:loss = 0.18562654, step = 6925 (94.793 sec)
# INFO:tensorflow:global_step/sec: 1.06802
# INFO:tensorflow:loss = 0.39156199, step = 7025 (93.632 sec)
# INFO:tensorflow:global_step/sec: 1.07082
# INFO:tensorflow:loss = 0.23126599, step = 7125 (93.387 sec)
# INFO:tensorflow:global_step/sec: 1.06947
# INFO:tensorflow:loss = 0.5394428, step = 7225 (93.504 sec)
# INFO:tensorflow:global_step/sec: 1.06993
# INFO:tensorflow:loss = 0.33088046, step = 7325 (93.464 sec)
# INFO:tensorflow:global_step/sec: 1.06879
# INFO:tensorflow:loss = 0.3363818, step = 7425 (93.564 sec)
# INFO:tensorflow:Saving checkpoints for 7500 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4402931.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-05:12:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-7500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-05:14:25
# INFO:tensorflow:Saving dict for global step 7500: accuracy = 0.8528125, global_step = 7500, loss = 0.4032206
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-7500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7501 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.26003012, step = 7500
# INFO:tensorflow:global_step/sec: 0.993071
# INFO:tensorflow:loss = 0.49783957, step = 7600 (100.699 sec)
# INFO:tensorflow:global_step/sec: 1.06745
# INFO:tensorflow:loss = 0.3169251, step = 7700 (93.681 sec)
# INFO:tensorflow:global_step/sec: 1.0708
# INFO:tensorflow:loss = 0.26131475, step = 7800 (93.388 sec)
# INFO:tensorflow:global_step/sec: 1.06645
# INFO:tensorflow:loss = 0.36061597, step = 7900 (93.769 sec)
# INFO:tensorflow:global_step/sec: 1.06816
# INFO:tensorflow:loss = 0.39002642, step = 8000 (93.619 sec)
# INFO:tensorflow:global_step/sec: 1.06806
# INFO:tensorflow:loss = 0.38866144, step = 8100 (93.628 sec)
# INFO:tensorflow:Saving checkpoints for 8133 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05335
# INFO:tensorflow:loss = 0.62366205, step = 8200 (94.936 sec)
# INFO:tensorflow:global_step/sec: 1.06968
# INFO:tensorflow:loss = 0.43155104, step = 8300 (93.486 sec)
# INFO:tensorflow:global_step/sec: 1.06995
# INFO:tensorflow:loss = 0.32236928, step = 8400 (93.462 sec)
# INFO:tensorflow:global_step/sec: 1.06814
# INFO:tensorflow:loss = 0.41107965, step = 8500 (93.621 sec)
# INFO:tensorflow:global_step/sec: 1.06988
# INFO:tensorflow:loss = 0.39000493, step = 8600 (93.468 sec)
# INFO:tensorflow:global_step/sec: 1.06891
# INFO:tensorflow:loss = 0.7188808, step = 8700 (93.553 sec)
# INFO:tensorflow:Saving checkpoints for 8774 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05403
# INFO:tensorflow:loss = 0.3385427, step = 8800 (94.874 sec)
# INFO:tensorflow:global_step/sec: 1.06987
# INFO:tensorflow:loss = 0.37586316, step = 8900 (93.469 sec)
# INFO:tensorflow:global_step/sec: 1.06769
# INFO:tensorflow:loss = 0.27782685, step = 9000 (93.660 sec)
# INFO:tensorflow:global_step/sec: 1.06757
# INFO:tensorflow:loss = 0.3923708, step = 9100 (93.671 sec)
# INFO:tensorflow:global_step/sec: 1.06842
# INFO:tensorflow:loss = 0.34651703, step = 9200 (93.596 sec)
# INFO:tensorflow:global_step/sec: 1.07088
# INFO:tensorflow:loss = 0.20435539, step = 9300 (93.381 sec)
# INFO:tensorflow:Saving checkpoints for 9375 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4391631.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-05:44:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-9375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-05:46:15
# INFO:tensorflow:Saving dict for global step 9375: accuracy = 0.8553125, global_step = 9375, loss = 0.39207515
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-9375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9376 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.6471248, step = 9375
# INFO:tensorflow:global_step/sec: 0.991133
# INFO:tensorflow:loss = 0.23863968, step = 9475 (100.896 sec)
# INFO:tensorflow:global_step/sec: 1.06705
# INFO:tensorflow:loss = 0.37819365, step = 9575 (93.716 sec)
# INFO:tensorflow:global_step/sec: 1.06873
# INFO:tensorflow:loss = 0.37817234, step = 9675 (93.569 sec)
# INFO:tensorflow:global_step/sec: 1.06861
# INFO:tensorflow:loss = 0.119376905, step = 9775 (93.580 sec)
# INFO:tensorflow:global_step/sec: 1.06929
# INFO:tensorflow:loss = 0.4357248, step = 9875 (93.520 sec)
# INFO:tensorflow:global_step/sec: 1.06777
# INFO:tensorflow:loss = 0.54272395, step = 9975 (93.653 sec)
# INFO:tensorflow:Saving checkpoints for 10008 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05417
# INFO:tensorflow:loss = 0.45062494, step = 10075 (94.861 sec)
# INFO:tensorflow:global_step/sec: 1.06779
# INFO:tensorflow:loss = 0.32332623, step = 10175 (93.651 sec)
# INFO:tensorflow:global_step/sec: 1.06762
# INFO:tensorflow:loss = 0.2660609, step = 10275 (93.666 sec)
# INFO:tensorflow:global_step/sec: 1.06952
# INFO:tensorflow:loss = 0.3742659, step = 10375 (93.500 sec)
# INFO:tensorflow:global_step/sec: 1.07037
# INFO:tensorflow:loss = 0.41649294, step = 10475 (93.425 sec)
# INFO:tensorflow:global_step/sec: 1.0711
# INFO:tensorflow:loss = 0.428062, step = 10575 (93.362 sec)
# INFO:tensorflow:Saving checkpoints for 10649 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05663
# INFO:tensorflow:loss = 0.37567386, step = 10675 (94.640 sec)
# INFO:tensorflow:global_step/sec: 1.06961
# INFO:tensorflow:loss = 0.6665109, step = 10775 (93.492 sec)
# INFO:tensorflow:global_step/sec: 1.06912
# INFO:tensorflow:loss = 0.5717409, step = 10875 (93.535 sec)
# INFO:tensorflow:global_step/sec: 1.07028
# INFO:tensorflow:loss = 0.4359702, step = 10975 (93.434 sec)
# INFO:tensorflow:global_step/sec: 1.0671
# INFO:tensorflow:loss = 0.5292865, step = 11075 (93.712 sec)
# INFO:tensorflow:global_step/sec: 1.06909
# INFO:tensorflow:loss = 0.22568713, step = 11175 (93.538 sec)
# INFO:tensorflow:Saving checkpoints for 11250 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5377705.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-06:16:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-11250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-06:18:04
# INFO:tensorflow:Saving dict for global step 11250: accuracy = 0.8615625, global_step = 11250, loss = 0.38516626
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-11250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 11251 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.50527865, step = 11250
# INFO:tensorflow:global_step/sec: 0.992593
# INFO:tensorflow:loss = 0.36851948, step = 11350 (100.747 sec)
# INFO:tensorflow:global_step/sec: 1.0676
# INFO:tensorflow:loss = 0.30525103, step = 11450 (93.668 sec)
# INFO:tensorflow:global_step/sec: 1.0702
# INFO:tensorflow:loss = 0.22689146, step = 11550 (93.440 sec)
# INFO:tensorflow:global_step/sec: 1.06848
# INFO:tensorflow:loss = 0.3042819, step = 11650 (93.590 sec)
# INFO:tensorflow:global_step/sec: 1.07016
# INFO:tensorflow:loss = 0.24173601, step = 11750 (93.444 sec)
# INFO:tensorflow:global_step/sec: 1.06837
# INFO:tensorflow:loss = 0.26521146, step = 11850 (93.601 sec)
# INFO:tensorflow:Saving checkpoints for 11884 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05665
# INFO:tensorflow:loss = 0.36640105, step = 11950 (94.638 sec)
# INFO:tensorflow:global_step/sec: 1.07029
# INFO:tensorflow:loss = 0.20235404, step = 12050 (93.433 sec)
# INFO:tensorflow:global_step/sec: 1.06948
# INFO:tensorflow:loss = 0.12654543, step = 12150 (93.503 sec)
# INFO:tensorflow:global_step/sec: 1.06954
# INFO:tensorflow:loss = 0.44969302, step = 12250 (93.499 sec)
# INFO:tensorflow:global_step/sec: 1.06939
# INFO:tensorflow:loss = 0.20095074, step = 12350 (93.511 sec)
# INFO:tensorflow:global_step/sec: 1.0689
# INFO:tensorflow:loss = 0.41414958, step = 12450 (93.554 sec)
# INFO:tensorflow:Saving checkpoints for 12525 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05468
# INFO:tensorflow:loss = 0.27920783, step = 12550 (94.815 sec)
# INFO:tensorflow:global_step/sec: 1.06817
# INFO:tensorflow:loss = 0.40548196, step = 12650 (93.618 sec)
# INFO:tensorflow:global_step/sec: 1.06972
# INFO:tensorflow:loss = 0.3077665, step = 12750 (93.482 sec)
# INFO:tensorflow:global_step/sec: 1.07004
# INFO:tensorflow:loss = 0.17862028, step = 12850 (93.454 sec)
# INFO:tensorflow:global_step/sec: 1.06771
# INFO:tensorflow:loss = 0.14155674, step = 12950 (93.658 sec)
# INFO:tensorflow:global_step/sec: 1.06847
# INFO:tensorflow:loss = 0.17935544, step = 13050 (93.592 sec)
# INFO:tensorflow:Saving checkpoints for 13125 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.38782743.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-06:48:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-13125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-06:49:53
# INFO:tensorflow:Saving dict for global step 13125: accuracy = 0.855, global_step = 13125, loss = 0.37895232
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-13125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13126 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.27875474, step = 13125
# INFO:tensorflow:global_step/sec: 0.992565
# INFO:tensorflow:loss = 0.3872407, step = 13225 (100.750 sec)
# INFO:tensorflow:global_step/sec: 1.06762
# INFO:tensorflow:loss = 0.43436256, step = 13325 (93.667 sec)
# INFO:tensorflow:global_step/sec: 1.0667
# INFO:tensorflow:loss = 0.18563473, step = 13425 (93.747 sec)
# INFO:tensorflow:global_step/sec: 1.06972
# INFO:tensorflow:loss = 0.35296163, step = 13525 (93.482 sec)
# INFO:tensorflow:global_step/sec: 1.06894
# INFO:tensorflow:loss = 0.4677664, step = 13625 (93.551 sec)
# INFO:tensorflow:global_step/sec: 1.06913
# INFO:tensorflow:loss = 0.45296958, step = 13725 (93.534 sec)
# INFO:tensorflow:Saving checkpoints for 13758 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05484
# INFO:tensorflow:loss = 0.5372521, step = 13825 (94.801 sec)
# INFO:tensorflow:global_step/sec: 1.06657
# INFO:tensorflow:loss = 0.76602685, step = 13925 (93.759 sec)
# INFO:tensorflow:global_step/sec: 1.06737
# INFO:tensorflow:loss = 0.4117933, step = 14025 (93.688 sec)
# INFO:tensorflow:global_step/sec: 1.07093
# INFO:tensorflow:loss = 0.36983025, step = 14125 (93.377 sec)
# INFO:tensorflow:global_step/sec: 1.07012
# INFO:tensorflow:loss = 0.21751681, step = 14225 (93.447 sec)
# INFO:tensorflow:global_step/sec: 1.06856
# INFO:tensorflow:loss = 0.24214275, step = 14325 (93.584 sec)
# INFO:tensorflow:Saving checkpoints for 14398 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.05369
# INFO:tensorflow:loss = 0.3579177, step = 14425 (94.905 sec)
# INFO:tensorflow:global_step/sec: 1.07013
# INFO:tensorflow:loss = 0.45553726, step = 14525 (93.446 sec)
# INFO:tensorflow:global_step/sec: 1.06945
# INFO:tensorflow:loss = 0.20939739, step = 14625 (93.506 sec)
# INFO:tensorflow:global_step/sec: 1.06983
# INFO:tensorflow:loss = 0.2875594, step = 14725 (93.473 sec)
# INFO:tensorflow:global_step/sec: 1.06863
# INFO:tensorflow:loss = 0.29342616, step = 14825 (93.578 sec)
# INFO:tensorflow:global_step/sec: 1.06946
# INFO:tensorflow:loss = 0.3241808, step = 14925 (93.505 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.35454476.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-16-07:20:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-16-07:21:43
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.8778125, global_step = 15000, loss = 0.3320559
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simpleoffnet/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15001 into models/simpleoffnet/model.ckpt.
# INFO:tensorflow:loss = 0.16582349, step = 15000
# INFO:tensorflow:global_step/sec: 0.990944
# INFO:tensorflow:loss = 0.16373874, step = 15100 (100.915 sec)
# INFO:tensorflow:global_step/sec: 1.06804
# INFO:tensorflow:loss = 0.60366136, step = 15200 (93.629 sec)
# INFO:tensorflow:global_step/sec: 1.0712
# INFO:tensorflow:loss = 0.35990435, step = 15300 (93.353 sec)
# INFO:tensorflow:global_step/sec: 1.07095
# INFO:tensorflow:loss = 0.23577811, step = 15400 (93.376 sec)
# INFO:tensorflow:global_step/sec: 1.06736
# INFO:tensorflow:loss = 0.18612939, step = 15500 (93.689 sec)

# %%
# estimator.evaluate(input_fn=lambda:tf.data.Dataset.from_tensor_slices(testing_data).batch(3).take(1))

# %%
# tuple(estimator.predict(input_fn=lambda:tf.data.Dataset.from_tensor_slices(testing_data).batch(3).take(1)))

# %%
# estimator.train(input_fn=training_dataset, steps=1)
