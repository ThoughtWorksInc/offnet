# %%
import mmh3

# %%
import functools

# %%
import iteration_utilities

# %%
import random

# %%
import numpy as np

# %%
import math

# %%
import tensorflow as tf

# %%
from tensorflow.python import debug as tf_debug

# %%
from enum import IntEnum

# %%
print("TensorFlow version: {}".format(tf.VERSION))
# Out:
# TensorFlow version: 1.8.0

# %%
# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
training_data, testing_data = tf.keras.datasets.fashion_mnist.load_data()

# %%
number_of_classes = int(np.max(testing_data[1])) + 1
number_of_input_channels = 1

# %%
number_of_experts = 1

# %%
number_of_hidden_layers = 20

# %%
number_of_features_per_layer = 32

# %%
paddings = (0, 0), (2, 2), (2, 2)

# %%
random_seed = number_of_hidden_layers

# %%
def offset_initializer():
    return tf.random_normal_initializer(stddev=1.0)
#     return tf.random_uniform_initializer(minval=-3.0, maxval=3.0)

# %%
def grid_sample(images, offset_x, offset_y):
    tf.assert_rank(images, 4)
    tf.assert_rank(offset_x, 4)
    tf.assert_rank(offset_y, 4)
    image_shape = tf.shape(images)
    current_batch_size = image_shape[0]
    width = image_shape[1]
    height = image_shape[2]
    number_of_features = image_shape[3]
    
    def check_width(tensor):
        if (tf.test.is_gpu_available()):
            return tensor
        else:
            return tf.maximum(tf.minimum(tensor, width - 1), 0)
    
    def check_height(tensor):
        if (tf.test.is_gpu_available()):
            return tensor
        else:
            return tf.maximum(tf.minimum(tensor, height - 1), 0)
    
    offset_left = tf.floor(offset_x)
    offset_top = tf.floor(offset_y)
    tf.assert_equal(tf.shape(offset_left), image_shape)
    tf.assert_equal(tf.shape(offset_top), image_shape)

    
    eps = 1e-7

    factor_right = offset_x - offset_left + eps
    factor_left = 1.0 + 2.0 * eps - factor_right
    factor_bottom = offset_y - offset_top + eps
    factor_top = 1.0 + 2.0 * eps - factor_bottom
    
    image_index, x_index, y_index, feature_index = tf.meshgrid(
        tf.range(current_batch_size, dtype=tf.int32),
        tf.range(width, dtype=tf.int32),
        tf.range(height, dtype=tf.int32),
        tf.range(number_of_features, dtype=tf.int32),
        indexing='ij',
    )

    left_index = check_width(x_index + tf.cast(offset_left, tf.int32))
    top_index = check_height(y_index + tf.cast(offset_top, tf.int32))

    right_index = left_index + 1
    bottom_index = top_index + 1
    
    tf.assert_rank(left_index, 4)
    tf.assert_rank(right_index, 4)
    tf.assert_rank(bottom_index, 4)
    tf.assert_rank(top_index, 4)
    
    images_top_left = tf.gather_nd(images, tf.stack((image_index, left_index, top_index, feature_index), axis=4))
    images_top_right = tf.gather_nd(images, tf.stack((image_index, right_index, top_index, feature_index), axis=4))
    images_bottom_left = tf.gather_nd(images, tf.stack((image_index, left_index, bottom_index, feature_index), axis=4))
    images_bottom_right = tf.gather_nd(images, tf.stack((image_index, right_index, bottom_index, feature_index), axis=4))

    tf.assert_rank(images_top_left, 4)
    tf.assert_rank(images_top_right, 4)
    tf.assert_rank(images_bottom_left, 4)
    tf.assert_rank(images_bottom_right, 4)

    lerp_top = factor_left * images_top_left + factor_right * images_top_right
    lerp_bottom = factor_left * images_bottom_left + factor_right * images_bottom_right
    output = factor_top * lerp_top + factor_bottom * lerp_bottom
    tf.assert_rank(output, 4)
    return output

# %%
def offnet(images, number_of_features, number_of_experts=None, name=None):
    with tf.variable_scope(name, default_name="offnet"):
        input_shape = images.shape
        if number_of_experts is None:
            number_of_experts = int(input_shape[0])
        number_of_input_features = int(input_shape[4])
        score_weight = tf.get_variable(
            name="score_weight",
            initializer=tf.random_normal_initializer(stddev=tf.sqrt(1.0 / number_of_input_features)),
            dtype=tf.float32,
            shape=(number_of_experts, number_of_input_features, number_of_features)
        )
        offset_x_weight = tf.get_variable(
            name="offset_x_weight",
            initializer=tf.random_normal_initializer(stddev=tf.sqrt(1.0 / number_of_input_features)),
            dtype=tf.float32,
            shape=(number_of_experts, number_of_input_features, number_of_features)
        )
        offset_y_weight = tf.get_variable(
            name="offset_y_weight",
            initializer=tf.random_normal_initializer(stddev=tf.sqrt(1.0 / number_of_input_features)),
            dtype=tf.float32,
            shape=(number_of_experts, number_of_input_features, number_of_features)
        )
        offset_x_bias = tf.get_variable(
            name="offset_x_bias",
            initializer=offset_initializer(),
            dtype=tf.float32,
            shape=(number_of_experts, 1, number_of_features),
        )
        offset_y_bias = tf.get_variable(
            name="offset_y_bias",
            initializer=offset_initializer(),
            dtype=tf.float32,
            shape=(number_of_experts, 1,  number_of_features),
        )
#         def scale_initializer():
#             return tf.sqrt(weight_scale / number_of_input_features)
#         score_scale = tf.get_variable(
#             name="score_scale",
#             initializer=scale_initializer(),
#             dtype=tf.float32
#         )
#         offset_x_scale = tf.get_variable(
#             name="offset_x_scale",
#             initializer=scale_initializer(),
#             dtype=tf.float32
#         )
#         offset_y_scale = tf.get_variable(
#             name="offset_y_scale",
#             initializer=scale_initializer(),
#             dtype=tf.float32
#         )
        
        dynamic_image_shape = tf.shape(images)
        images_3d = tf.reshape(
            images,
            (
                number_of_experts,
                dynamic_image_shape[1] * dynamic_image_shape[2] * dynamic_image_shape[3],
                number_of_input_features
            )
        )
        def images_xw_plus_b(w, b):
            tf.matmul(images_3d, w) + b
        
        def to_4d(images):
            tf.assert_equal(tf.shape(images), (number_of_experts, dynamic_image_shape[1] * dynamic_image_shape[2] * dynamic_image_shape[3], number_of_features))
            return tf.reshape(
                images,
                (
                    number_of_experts * dynamic_image_shape[1],
                    dynamic_image_shape[2],
                    dynamic_image_shape[3],
                    number_of_features
                )
            )
        return tf.reshape(
            grid_sample(
                to_4d(tf.matmul(images_3d, score_weight)),
                to_4d(tf.matmul(images_3d, offset_x_weight) + offset_x_bias),
                to_4d(tf.matmul(images_3d, offset_y_weight) + offset_y_bias)
            ),
            (
                number_of_experts,
                dynamic_image_shape[1],
                dynamic_image_shape[2],
                dynamic_image_shape[3],
                number_of_features
            )
        )

# %%
number_of_horizontal_samples = 3
number_of_vertical_samples = 3

# %%
def model_fn(features, labels, mode, params, config):
    random.seed(number_of_hidden_layers)
    padded_input = tf.expand_dims(
        tf.expand_dims(
            tf.pad(tf.cast(features, tf.float32) / 255.0 - 0.5, paddings),
            axis=0
        ),
        axis=4
    )
    width = int(padded_input.shape[2])
    height = int(padded_input.shape[3])
    
    layers = functools.reduce(
        lambda features, i: tf.nn.relu(tf.layers.batch_normalization(
            offnet(features, number_of_features_per_layer, 1),
            training=mode is tf.estimator.ModeKeys.TRAIN
        )),
        range(number_of_hidden_layers),
        padded_input
    )
    score_layer = offnet(layers, number_of_classes, number_of_experts)
    scores = tf.reduce_mean(
        tf.reduce_mean(
            score_layer,
            axis=0
        )[
            :,
            int(width / (number_of_horizontal_samples + 1)):int(width * number_of_horizontal_samples / (number_of_horizontal_samples + 1)):int(width / (number_of_horizontal_samples + 1)),
            int(height / (number_of_horizontal_samples + 1)):int(height * number_of_horizontal_samples / (number_of_horizontal_samples + 1)):int(height / (number_of_horizontal_samples + 1)),
            :
        ],
        axis=(1, 2)
    )

    probabilities = tf.nn.softmax(logits=scores)
    predicted_classes = tf.argmax(scores, 1)
    predictions = {
        'probabilities' : probabilities,
        'scores': scores,
        'class': predicted_classes,
    }

    optimizer = tf.train.AdamOptimizer(epsilon=0.1)
    if labels is None:
        return tf.estimator.EstimatorSpec(
            mode=mode,
            predictions=predictions,
        )
    else:
        loss = tf.losses.softmax_cross_entropy(logits=scores, onehot_labels=tf.one_hot(labels, number_of_classes))
        eval_metric_ops = {
            'accuracy': tf.metrics.accuracy(labels=labels, predictions=predicted_classes)
        }
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            return tf.estimator.EstimatorSpec(
                mode=mode,
                predictions=predictions,
                loss=loss,
                train_op=optimizer.minimize(loss, global_step=tf.train.get_global_step()),
                eval_metric_ops=eval_metric_ops,
            )

# %%
run_config = tf.estimator.RunConfig(
    model_dir=f"models/simplereluoffnet{number_of_features_per_layer}x{number_of_hidden_layers}",
    session_config=tf.ConfigProto(
        gpu_options=tf.GPUOptions(
            allow_growth=True,
        ),
        graph_options=tf.GraphOptions(
            optimizer_options=tf.OptimizerOptions(
                global_jit_level=tf.OptimizerOptions.ON_2,
                do_function_inlining=True,
                do_constant_folding=True,
                do_common_subexpression_elimination=True,
            ),
        )
    )
)

# %%
estimator = tf.estimator.Estimator(model_fn, config=run_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'models/simplereluoffnet32x20', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   allow_growth: true
# }
# graph_options {
#   optimizer_options {
#     do_common_subexpression_elimination: true
#     do_constant_folding: true
#     do_function_inlining: true
#     global_jit_level: ON_2
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff4b56bf320>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x7ff4b56b3e18>) includes params argument, but params are not passed to Estimator.

# %%
batch_size = 32

# %%
def training_dataset():
    return tf.data.Dataset.from_tensor_slices(training_data).shuffle(1000).batch(batch_size)

# %%
def testing_dataset():
    return tf.data.Dataset.from_tensor_slices(testing_data).batch(batch_size)

# %%
# hook = tf_debug.TensorBoardDebugHook("localhost:6064")
# estimator.train(training_dataset,hooks=[hook])

# %%
tf.estimator.train_and_evaluate(
    estimator,
    train_spec=tf.estimator.TrainSpec(training_dataset),
    eval_spec=tf.estimator.EvalSpec(testing_dataset, throttle_secs=1800)
)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 1800 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 2.2942164, step = 0
# INFO:tensorflow:global_step/sec: 1.10784
# INFO:tensorflow:loss = 2.3278217, step = 100 (90.267 sec)
# INFO:tensorflow:global_step/sec: 1.20797
# INFO:tensorflow:loss = 2.251985, step = 200 (82.783 sec)
# INFO:tensorflow:global_step/sec: 1.20618
# INFO:tensorflow:loss = 2.2821088, step = 300 (82.907 sec)
# INFO:tensorflow:global_step/sec: 1.20517
# INFO:tensorflow:loss = 2.333963, step = 400 (82.976 sec)
# INFO:tensorflow:global_step/sec: 1.20636
# INFO:tensorflow:loss = 2.1554809, step = 500 (82.894 sec)
# INFO:tensorflow:global_step/sec: 1.20463
# INFO:tensorflow:loss = 2.2960842, step = 600 (83.013 sec)
# INFO:tensorflow:global_step/sec: 1.20459
# INFO:tensorflow:loss = 2.1370983, step = 700 (83.016 sec)
# INFO:tensorflow:Saving checkpoints for 714 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18787
# INFO:tensorflow:loss = 2.0109906, step = 800 (84.184 sec)
# INFO:tensorflow:global_step/sec: 1.20579
# INFO:tensorflow:loss = 1.749528, step = 900 (82.934 sec)
# INFO:tensorflow:global_step/sec: 1.20529
# INFO:tensorflow:loss = 1.8929079, step = 1000 (82.968 sec)
# INFO:tensorflow:global_step/sec: 1.20428
# INFO:tensorflow:loss = 1.9250621, step = 1100 (83.037 sec)
# INFO:tensorflow:global_step/sec: 1.20441
# INFO:tensorflow:loss = 1.7932436, step = 1200 (83.028 sec)
# INFO:tensorflow:global_step/sec: 1.20622
# INFO:tensorflow:loss = 1.7238587, step = 1300 (82.904 sec)
# INFO:tensorflow:global_step/sec: 1.2066
# INFO:tensorflow:loss = 1.5922232, step = 1400 (82.878 sec)
# INFO:tensorflow:Saving checkpoints for 1436 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18845
# INFO:tensorflow:loss = 1.3443519, step = 1500 (84.143 sec)
# INFO:tensorflow:global_step/sec: 1.20598
# INFO:tensorflow:loss = 1.1161684, step = 1600 (82.920 sec)
# INFO:tensorflow:global_step/sec: 1.206
# INFO:tensorflow:loss = 1.2263899, step = 1700 (82.919 sec)
# INFO:tensorflow:global_step/sec: 1.20326
# INFO:tensorflow:loss = 0.93072283, step = 1800 (83.107 sec)
# INFO:tensorflow:Saving checkpoints for 1875 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1147301.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-02:01:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-1875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-02:02:28
# INFO:tensorflow:Saving dict for global step 1875: accuracy = 0.6284375, global_step = 1875, loss = 1.0345782
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-1875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1876 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 1.107657, step = 1875
# INFO:tensorflow:global_step/sec: 1.10935
# INFO:tensorflow:loss = 0.978256, step = 1975 (90.143 sec)
# INFO:tensorflow:global_step/sec: 1.20466
# INFO:tensorflow:loss = 1.2037184, step = 2075 (83.011 sec)
# INFO:tensorflow:global_step/sec: 1.20241
# INFO:tensorflow:loss = 1.0062716, step = 2175 (83.167 sec)
# INFO:tensorflow:global_step/sec: 1.20456
# INFO:tensorflow:loss = 0.9910907, step = 2275 (83.018 sec)
# INFO:tensorflow:global_step/sec: 1.20335
# INFO:tensorflow:loss = 0.94023, step = 2375 (83.101 sec)
# INFO:tensorflow:global_step/sec: 1.20576
# INFO:tensorflow:loss = 1.1840382, step = 2475 (82.935 sec)
# INFO:tensorflow:global_step/sec: 1.20584
# INFO:tensorflow:loss = 0.9144126, step = 2575 (82.929 sec)
# INFO:tensorflow:Saving checkpoints for 2589 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18639
# INFO:tensorflow:loss = 0.6421863, step = 2675 (84.289 sec)
# INFO:tensorflow:global_step/sec: 1.20626
# INFO:tensorflow:loss = 0.71168137, step = 2775 (82.901 sec)
# INFO:tensorflow:global_step/sec: 1.20631
# INFO:tensorflow:loss = 0.60749036, step = 2875 (82.897 sec)
# INFO:tensorflow:global_step/sec: 1.20562
# INFO:tensorflow:loss = 0.7852671, step = 2975 (82.945 sec)
# INFO:tensorflow:global_step/sec: 1.20522
# INFO:tensorflow:loss = 0.8104272, step = 3075 (82.972 sec)
# INFO:tensorflow:global_step/sec: 1.20677
# INFO:tensorflow:loss = 1.0558363, step = 3175 (82.865 sec)
# INFO:tensorflow:global_step/sec: 1.20556
# INFO:tensorflow:loss = 0.73569524, step = 3275 (82.949 sec)
# INFO:tensorflow:Saving checkpoints for 3311 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18775
# INFO:tensorflow:loss = 0.68349326, step = 3375 (84.192 sec)
# INFO:tensorflow:global_step/sec: 1.20528
# INFO:tensorflow:loss = 0.754521, step = 3475 (82.969 sec)
# INFO:tensorflow:global_step/sec: 1.2026
# INFO:tensorflow:loss = 0.48013481, step = 3575 (83.153 sec)
# INFO:tensorflow:global_step/sec: 1.20605
# INFO:tensorflow:loss = 0.5523044, step = 3675 (82.915 sec)
# INFO:tensorflow:Saving checkpoints for 3750 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.6460643.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-02:29:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-3750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-02:30:50
# INFO:tensorflow:Saving dict for global step 3750: accuracy = 0.748125, global_step = 3750, loss = 0.6859436
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-3750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3751 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.86823225, step = 3750
# INFO:tensorflow:global_step/sec: 1.1091
# INFO:tensorflow:loss = 0.9399698, step = 3850 (90.164 sec)
# INFO:tensorflow:global_step/sec: 1.20458
# INFO:tensorflow:loss = 0.9513545, step = 3950 (83.017 sec)
# INFO:tensorflow:global_step/sec: 1.20379
# INFO:tensorflow:loss = 0.8552134, step = 4050 (83.071 sec)
# INFO:tensorflow:global_step/sec: 1.20341
# INFO:tensorflow:loss = 0.6978363, step = 4150 (83.097 sec)
# INFO:tensorflow:global_step/sec: 1.20555
# INFO:tensorflow:loss = 0.55518323, step = 4250 (82.950 sec)
# INFO:tensorflow:global_step/sec: 1.20504
# INFO:tensorflow:loss = 0.6306056, step = 4350 (82.985 sec)
# INFO:tensorflow:global_step/sec: 1.20635
# INFO:tensorflow:loss = 0.80847466, step = 4450 (82.894 sec)
# INFO:tensorflow:Saving checkpoints for 4464 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18728
# INFO:tensorflow:loss = 0.9415648, step = 4550 (84.227 sec)
# INFO:tensorflow:global_step/sec: 1.20581
# INFO:tensorflow:loss = 0.58358943, step = 4650 (82.932 sec)
# INFO:tensorflow:global_step/sec: 1.20558
# INFO:tensorflow:loss = 0.68224823, step = 4750 (82.948 sec)
# INFO:tensorflow:global_step/sec: 1.20272
# INFO:tensorflow:loss = 0.5464735, step = 4850 (83.145 sec)
# INFO:tensorflow:global_step/sec: 1.20463
# INFO:tensorflow:loss = 0.4329256, step = 4950 (83.013 sec)
# INFO:tensorflow:global_step/sec: 1.20279
# INFO:tensorflow:loss = 0.5665639, step = 5050 (83.140 sec)
# INFO:tensorflow:global_step/sec: 1.20423
# INFO:tensorflow:loss = 0.6380728, step = 5150 (83.041 sec)
# INFO:tensorflow:Saving checkpoints for 5186 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18402
# INFO:tensorflow:loss = 0.31238797, step = 5250 (84.458 sec)
# INFO:tensorflow:global_step/sec: 1.20459
# INFO:tensorflow:loss = 0.6957886, step = 5350 (83.016 sec)
# INFO:tensorflow:global_step/sec: 1.20294
# INFO:tensorflow:loss = 0.48628864, step = 5450 (83.129 sec)
# INFO:tensorflow:global_step/sec: 1.20452
# INFO:tensorflow:loss = 0.74943054, step = 5550 (83.021 sec)
# INFO:tensorflow:Saving checkpoints for 5625 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3220514.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-02:57:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-5625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-02:59:11
# INFO:tensorflow:Saving dict for global step 5625: accuracy = 0.7825, global_step = 5625, loss = 0.60275126
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-5625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5626 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.52083296, step = 5625
# INFO:tensorflow:global_step/sec: 1.11216
# INFO:tensorflow:loss = 0.63924134, step = 5725 (89.916 sec)
# INFO:tensorflow:global_step/sec: 1.20588
# INFO:tensorflow:loss = 0.5114001, step = 5825 (82.927 sec)
# INFO:tensorflow:global_step/sec: 1.20514
# INFO:tensorflow:loss = 0.50200313, step = 5925 (82.978 sec)
# INFO:tensorflow:global_step/sec: 1.20295
# INFO:tensorflow:loss = 0.648785, step = 6025 (83.129 sec)
# INFO:tensorflow:global_step/sec: 1.20238
# INFO:tensorflow:loss = 0.8218647, step = 6125 (83.168 sec)
# INFO:tensorflow:global_step/sec: 1.20704
# INFO:tensorflow:loss = 0.6344986, step = 6225 (82.847 sec)
# INFO:tensorflow:global_step/sec: 1.20599
# INFO:tensorflow:loss = 0.47530743, step = 6325 (82.919 sec)
# INFO:tensorflow:Saving checkpoints for 6339 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18809
# INFO:tensorflow:loss = 0.5434942, step = 6425 (84.169 sec)
# INFO:tensorflow:global_step/sec: 1.20704
# INFO:tensorflow:loss = 0.46987617, step = 6525 (82.848 sec)
# INFO:tensorflow:global_step/sec: 1.20223
# INFO:tensorflow:loss = 0.68503165, step = 6625 (83.179 sec)
# INFO:tensorflow:global_step/sec: 1.20354
# INFO:tensorflow:loss = 0.43618265, step = 6725 (83.088 sec)
# INFO:tensorflow:global_step/sec: 1.20388
# INFO:tensorflow:loss = 0.28342304, step = 6825 (83.065 sec)
# INFO:tensorflow:global_step/sec: 1.20581
# INFO:tensorflow:loss = 0.56293976, step = 6925 (82.932 sec)
# INFO:tensorflow:global_step/sec: 1.20578
# INFO:tensorflow:loss = 0.49973077, step = 7025 (82.934 sec)
# INFO:tensorflow:Saving checkpoints for 7061 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.1866
# INFO:tensorflow:loss = 0.31056154, step = 7125 (84.274 sec)
# INFO:tensorflow:global_step/sec: 1.2032
# INFO:tensorflow:loss = 0.26522714, step = 7225 (83.112 sec)
# INFO:tensorflow:global_step/sec: 1.20583
# INFO:tensorflow:loss = 0.3376324, step = 7325 (82.930 sec)
# INFO:tensorflow:global_step/sec: 1.20553
# INFO:tensorflow:loss = 0.41456, step = 7425 (82.951 sec)
# INFO:tensorflow:Saving checkpoints for 7500 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4611938.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-03:26:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-7500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-03:27:31
# INFO:tensorflow:Saving dict for global step 7500: accuracy = 0.8115625, global_step = 7500, loss = 0.52135843
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-7500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7501 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.7502697, step = 7500
# INFO:tensorflow:global_step/sec: 1.10536
# INFO:tensorflow:loss = 0.4414464, step = 7600 (90.469 sec)
# INFO:tensorflow:global_step/sec: 1.20391
# INFO:tensorflow:loss = 0.4376114, step = 7700 (83.063 sec)
# INFO:tensorflow:global_step/sec: 1.20286
# INFO:tensorflow:loss = 0.2935852, step = 7800 (83.135 sec)
# INFO:tensorflow:global_step/sec: 1.20606
# INFO:tensorflow:loss = 0.6151581, step = 7900 (82.914 sec)
# INFO:tensorflow:global_step/sec: 1.20177
# INFO:tensorflow:loss = 0.3821563, step = 8000 (83.210 sec)
# INFO:tensorflow:global_step/sec: 1.20404
# INFO:tensorflow:loss = 0.38531554, step = 8100 (83.054 sec)
# INFO:tensorflow:global_step/sec: 1.20418
# INFO:tensorflow:loss = 0.23410437, step = 8200 (83.044 sec)
# INFO:tensorflow:Saving checkpoints for 8213 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18623
# INFO:tensorflow:loss = 0.5502161, step = 8300 (84.301 sec)
# INFO:tensorflow:global_step/sec: 1.20295
# INFO:tensorflow:loss = 0.3110479, step = 8400 (83.128 sec)
# INFO:tensorflow:global_step/sec: 1.20003
# INFO:tensorflow:loss = 0.43240517, step = 8500 (83.332 sec)
# INFO:tensorflow:global_step/sec: 1.20294
# INFO:tensorflow:loss = 0.3804458, step = 8600 (83.129 sec)
# INFO:tensorflow:global_step/sec: 1.20386
# INFO:tensorflow:loss = 0.18517357, step = 8700 (83.066 sec)
# INFO:tensorflow:global_step/sec: 1.20276
# INFO:tensorflow:loss = 0.5352376, step = 8800 (83.141 sec)
# INFO:tensorflow:global_step/sec: 1.20422
# INFO:tensorflow:loss = 0.3204255, step = 8900 (83.041 sec)
# INFO:tensorflow:Saving checkpoints for 8934 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18454
# INFO:tensorflow:loss = 0.27309382, step = 9000 (84.421 sec)
# INFO:tensorflow:global_step/sec: 1.20239
# INFO:tensorflow:loss = 0.6262007, step = 9100 (83.168 sec)
# INFO:tensorflow:global_step/sec: 1.20219
# INFO:tensorflow:loss = 0.31653422, step = 9200 (83.182 sec)
# INFO:tensorflow:global_step/sec: 1.20526
# INFO:tensorflow:loss = 0.60968405, step = 9300 (82.970 sec)
# INFO:tensorflow:Saving checkpoints for 9375 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5134648.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-03:54:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-9375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-03:55:54
# INFO:tensorflow:Saving dict for global step 9375: accuracy = 0.8315625, global_step = 9375, loss = 0.46885037
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-9375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9376 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.46279222, step = 9375
# INFO:tensorflow:global_step/sec: 1.10659
# INFO:tensorflow:loss = 0.463633, step = 9475 (90.368 sec)
# INFO:tensorflow:global_step/sec: 1.20483
# INFO:tensorflow:loss = 0.46564007, step = 9575 (82.999 sec)
# INFO:tensorflow:global_step/sec: 1.20547
# INFO:tensorflow:loss = 0.5656028, step = 9675 (82.955 sec)
# INFO:tensorflow:global_step/sec: 1.20842
# INFO:tensorflow:loss = 0.63631827, step = 9775 (82.753 sec)
# INFO:tensorflow:global_step/sec: 1.20517
# INFO:tensorflow:loss = 0.42271793, step = 9875 (82.975 sec)
# INFO:tensorflow:global_step/sec: 1.20329
# INFO:tensorflow:loss = 0.4786973, step = 9975 (83.106 sec)
# INFO:tensorflow:global_step/sec: 1.20512
# INFO:tensorflow:loss = 0.80162203, step = 10075 (82.979 sec)
# INFO:tensorflow:Saving checkpoints for 10089 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18782
# INFO:tensorflow:loss = 0.4167081, step = 10175 (84.188 sec)
# INFO:tensorflow:global_step/sec: 1.20435
# INFO:tensorflow:loss = 0.56540585, step = 10275 (83.032 sec)
# INFO:tensorflow:global_step/sec: 1.2049
# INFO:tensorflow:loss = 0.23749381, step = 10375 (82.995 sec)
# INFO:tensorflow:global_step/sec: 1.20469
# INFO:tensorflow:loss = 0.270554, step = 10475 (83.009 sec)
# INFO:tensorflow:global_step/sec: 1.20415
# INFO:tensorflow:loss = 0.36531883, step = 10575 (83.046 sec)
# INFO:tensorflow:global_step/sec: 1.20461
# INFO:tensorflow:loss = 0.38775206, step = 10675 (83.014 sec)
# INFO:tensorflow:global_step/sec: 1.20514
# INFO:tensorflow:loss = 0.27078873, step = 10775 (82.978 sec)
# INFO:tensorflow:Saving checkpoints for 10811 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18764
# INFO:tensorflow:loss = 0.29906186, step = 10875 (84.200 sec)
# INFO:tensorflow:global_step/sec: 1.20416
# INFO:tensorflow:loss = 0.3452748, step = 10975 (83.046 sec)
# INFO:tensorflow:global_step/sec: 1.20487
# INFO:tensorflow:loss = 0.219975, step = 11075 (82.996 sec)
# INFO:tensorflow:global_step/sec: 1.20385
# INFO:tensorflow:loss = 0.72617656, step = 11175 (83.067 sec)
# INFO:tensorflow:Saving checkpoints for 11250 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.44972664.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-04:22:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-11250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-04:24:15
# INFO:tensorflow:Saving dict for global step 11250: accuracy = 0.8284375, global_step = 11250, loss = 0.4733704
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-11250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 11251 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.46048966, step = 11250
# INFO:tensorflow:global_step/sec: 1.10784
# INFO:tensorflow:loss = 0.09959136, step = 11350 (90.266 sec)
# INFO:tensorflow:global_step/sec: 1.20345
# INFO:tensorflow:loss = 0.38320494, step = 11450 (83.095 sec)
# INFO:tensorflow:global_step/sec: 1.20691
# INFO:tensorflow:loss = 0.8165399, step = 11550 (82.856 sec)
# INFO:tensorflow:global_step/sec: 1.20165
# INFO:tensorflow:loss = 0.56525886, step = 11650 (83.219 sec)
# INFO:tensorflow:global_step/sec: 1.2057
# INFO:tensorflow:loss = 0.35424405, step = 11750 (82.939 sec)
# INFO:tensorflow:global_step/sec: 1.20485
# INFO:tensorflow:loss = 0.61240655, step = 11850 (82.998 sec)
# INFO:tensorflow:global_step/sec: 1.20317
# INFO:tensorflow:loss = 0.4008206, step = 11950 (83.114 sec)
# INFO:tensorflow:Saving checkpoints for 11964 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18535
# INFO:tensorflow:loss = 0.35920188, step = 12050 (84.363 sec)
# INFO:tensorflow:global_step/sec: 1.20722
# INFO:tensorflow:loss = 0.5536394, step = 12150 (82.835 sec)
# INFO:tensorflow:global_step/sec: 1.20281
# INFO:tensorflow:loss = 0.38224363, step = 12250 (83.139 sec)
# INFO:tensorflow:global_step/sec: 1.20758
# INFO:tensorflow:loss = 0.75492924, step = 12350 (82.810 sec)
# INFO:tensorflow:global_step/sec: 1.1634
# INFO:tensorflow:loss = 0.37575388, step = 12450 (85.955 sec)
# INFO:tensorflow:global_step/sec: 1.19873
# INFO:tensorflow:loss = 0.5662544, step = 12550 (83.421 sec)
# INFO:tensorflow:global_step/sec: 1.20557
# INFO:tensorflow:loss = 0.3617497, step = 12650 (82.948 sec)
# INFO:tensorflow:Saving checkpoints for 12682 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18881
# INFO:tensorflow:loss = 0.37372336, step = 12750 (84.117 sec)
# INFO:tensorflow:global_step/sec: 1.20529
# INFO:tensorflow:loss = 0.3271037, step = 12850 (82.968 sec)
# INFO:tensorflow:global_step/sec: 1.20449
# INFO:tensorflow:loss = 0.2114177, step = 12950 (83.023 sec)
# INFO:tensorflow:global_step/sec: 1.2059
# INFO:tensorflow:loss = 0.22472341, step = 13050 (82.926 sec)
# INFO:tensorflow:Saving checkpoints for 13125 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.32171136.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-04:51:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-13125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-04:52:39
# INFO:tensorflow:Saving dict for global step 13125: accuracy = 0.8428125, global_step = 13125, loss = 0.42052025
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-13125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13126 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.58314407, step = 13125
# INFO:tensorflow:global_step/sec: 1.1056
# INFO:tensorflow:loss = 0.45472068, step = 13225 (90.449 sec)
# INFO:tensorflow:global_step/sec: 1.20376
# INFO:tensorflow:loss = 0.5854492, step = 13325 (83.073 sec)
# INFO:tensorflow:global_step/sec: 1.20681
# INFO:tensorflow:loss = 0.46972716, step = 13425 (82.863 sec)
# INFO:tensorflow:global_step/sec: 1.20303
# INFO:tensorflow:loss = 0.42685694, step = 13525 (83.124 sec)
# INFO:tensorflow:global_step/sec: 1.20322
# INFO:tensorflow:loss = 0.22438553, step = 13625 (83.110 sec)
# INFO:tensorflow:global_step/sec: 1.20272
# INFO:tensorflow:loss = 0.40254295, step = 13725 (83.145 sec)
# INFO:tensorflow:global_step/sec: 1.20653
# INFO:tensorflow:loss = 0.32394296, step = 13825 (82.882 sec)
# INFO:tensorflow:Saving checkpoints for 13838 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18729
# INFO:tensorflow:loss = 0.3060173, step = 13925 (84.226 sec)
# INFO:tensorflow:global_step/sec: 1.20571
# INFO:tensorflow:loss = 0.30941594, step = 14025 (82.939 sec)
# INFO:tensorflow:global_step/sec: 1.20371
# INFO:tensorflow:loss = 0.27018523, step = 14125 (83.076 sec)
# INFO:tensorflow:global_step/sec: 1.20375
# INFO:tensorflow:loss = 0.26085097, step = 14225 (83.074 sec)
# INFO:tensorflow:global_step/sec: 1.20607
# INFO:tensorflow:loss = 0.22630723, step = 14325 (82.913 sec)
# INFO:tensorflow:global_step/sec: 1.20253
# INFO:tensorflow:loss = 0.4987068, step = 14425 (83.158 sec)
# INFO:tensorflow:global_step/sec: 1.20458
# INFO:tensorflow:loss = 0.24995628, step = 14525 (83.017 sec)
# INFO:tensorflow:Saving checkpoints for 14560 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18773
# INFO:tensorflow:loss = 0.21234111, step = 14625 (84.194 sec)
# INFO:tensorflow:global_step/sec: 1.20518
# INFO:tensorflow:loss = 0.21955362, step = 14725 (82.975 sec)
# INFO:tensorflow:global_step/sec: 1.20569
# INFO:tensorflow:loss = 0.2521299, step = 14825 (82.940 sec)
# INFO:tensorflow:global_step/sec: 1.20517
# INFO:tensorflow:loss = 0.33423027, step = 14925 (82.976 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.39952904.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-05:19:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-05:21:00
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.8353125, global_step = 15000, loss = 0.45270234
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15001 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.5557157, step = 15000
# INFO:tensorflow:global_step/sec: 1.10631
# INFO:tensorflow:loss = 0.5777768, step = 15100 (90.391 sec)
# INFO:tensorflow:global_step/sec: 1.20459
# INFO:tensorflow:loss = 0.61179686, step = 15200 (83.016 sec)
# INFO:tensorflow:global_step/sec: 1.20334
# INFO:tensorflow:loss = 0.3376981, step = 15300 (83.102 sec)
# INFO:tensorflow:global_step/sec: 1.20678
# INFO:tensorflow:loss = 0.3822675, step = 15400 (82.865 sec)
# INFO:tensorflow:global_step/sec: 1.20715
# INFO:tensorflow:loss = 0.29056263, step = 15500 (82.840 sec)
# INFO:tensorflow:global_step/sec: 1.20644
# INFO:tensorflow:loss = 0.6411098, step = 15600 (82.889 sec)
# INFO:tensorflow:global_step/sec: 1.20613
# INFO:tensorflow:loss = 0.39312744, step = 15700 (82.910 sec)
# INFO:tensorflow:Saving checkpoints for 15714 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18686
# INFO:tensorflow:loss = 0.41477108, step = 15800 (84.256 sec)
# INFO:tensorflow:global_step/sec: 1.20391
# INFO:tensorflow:loss = 0.25133508, step = 15900 (83.062 sec)
# INFO:tensorflow:global_step/sec: 1.20408
# INFO:tensorflow:loss = 0.29734847, step = 16000 (83.051 sec)
# INFO:tensorflow:global_step/sec: 1.20467
# INFO:tensorflow:loss = 0.36194327, step = 16100 (83.010 sec)
# INFO:tensorflow:global_step/sec: 1.2034
# INFO:tensorflow:loss = 0.3032787, step = 16200 (83.098 sec)
# INFO:tensorflow:global_step/sec: 1.20273
# INFO:tensorflow:loss = 0.34532374, step = 16300 (83.144 sec)
# INFO:tensorflow:global_step/sec: 1.20379
# INFO:tensorflow:loss = 0.44346726, step = 16400 (83.072 sec)
# INFO:tensorflow:Saving checkpoints for 16435 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18773
# INFO:tensorflow:loss = 0.28468752, step = 16500 (84.194 sec)
# INFO:tensorflow:global_step/sec: 1.2037
# INFO:tensorflow:loss = 0.2447828, step = 16600 (83.077 sec)
# INFO:tensorflow:global_step/sec: 1.20552
# INFO:tensorflow:loss = 0.17975028, step = 16700 (82.951 sec)
# INFO:tensorflow:global_step/sec: 1.20416
# INFO:tensorflow:loss = 0.31940022, step = 16800 (83.046 sec)
# INFO:tensorflow:Saving checkpoints for 16875 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.23067701.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-05:48:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-16875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-05:49:20
# INFO:tensorflow:Saving dict for global step 16875: accuracy = 0.860625, global_step = 16875, loss = 0.3886328
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-16875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 16876 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.18778934, step = 16875
# INFO:tensorflow:global_step/sec: 1.10005
# INFO:tensorflow:loss = 0.48573938, step = 16975 (90.906 sec)
# INFO:tensorflow:global_step/sec: 1.20315
# INFO:tensorflow:loss = 0.45248416, step = 17075 (83.115 sec)
# INFO:tensorflow:global_step/sec: 1.20492
# INFO:tensorflow:loss = 0.42676094, step = 17175 (82.993 sec)
# INFO:tensorflow:global_step/sec: 1.20795
# INFO:tensorflow:loss = 0.30879563, step = 17275 (82.785 sec)
# INFO:tensorflow:global_step/sec: 1.20597
# INFO:tensorflow:loss = 0.6413516, step = 17375 (82.920 sec)
# INFO:tensorflow:global_step/sec: 1.20559
# INFO:tensorflow:loss = 0.3992672, step = 17475 (82.947 sec)
# INFO:tensorflow:global_step/sec: 1.20668
# INFO:tensorflow:loss = 0.48085475, step = 17575 (82.872 sec)
# INFO:tensorflow:Saving checkpoints for 17589 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18607
# INFO:tensorflow:loss = 0.2302201, step = 17675 (84.312 sec)
# INFO:tensorflow:global_step/sec: 1.20666
# INFO:tensorflow:loss = 0.27001488, step = 17775 (82.873 sec)
# INFO:tensorflow:global_step/sec: 1.20643
# INFO:tensorflow:loss = 0.28773233, step = 17875 (82.889 sec)
# INFO:tensorflow:global_step/sec: 1.20655
# INFO:tensorflow:loss = 0.31591612, step = 17975 (82.881 sec)
# INFO:tensorflow:global_step/sec: 1.20667
# INFO:tensorflow:loss = 0.24905387, step = 18075 (82.873 sec)
# INFO:tensorflow:global_step/sec: 1.206
# INFO:tensorflow:loss = 0.34800768, step = 18175 (82.919 sec)
# INFO:tensorflow:global_step/sec: 1.2041
# INFO:tensorflow:loss = 0.37502474, step = 18275 (83.050 sec)
# INFO:tensorflow:Saving checkpoints for 18311 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18775
# INFO:tensorflow:loss = 0.38844183, step = 18375 (84.193 sec)
# INFO:tensorflow:global_step/sec: 1.20669
# INFO:tensorflow:loss = 0.47562164, step = 18475 (82.872 sec)
# INFO:tensorflow:global_step/sec: 1.20781
# INFO:tensorflow:loss = 0.34594846, step = 18575 (82.794 sec)
# INFO:tensorflow:global_step/sec: 1.20632
# INFO:tensorflow:loss = 0.29872674, step = 18675 (82.897 sec)
# INFO:tensorflow:Saving checkpoints for 18750 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.32663074.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-06:16:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-18750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-06:17:40
# INFO:tensorflow:Saving dict for global step 18750: accuracy = 0.8534375, global_step = 18750, loss = 0.39258626
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-18750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 18751 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.1851125, step = 18750
# INFO:tensorflow:global_step/sec: 1.10729
# INFO:tensorflow:loss = 0.2515566, step = 18850 (90.311 sec)
# INFO:tensorflow:global_step/sec: 1.20273
# INFO:tensorflow:loss = 0.29740107, step = 18950 (83.144 sec)
# INFO:tensorflow:global_step/sec: 1.20291
# INFO:tensorflow:loss = 0.34469986, step = 19050 (83.132 sec)
# INFO:tensorflow:global_step/sec: 1.20647
# INFO:tensorflow:loss = 0.21775399, step = 19150 (82.886 sec)
# INFO:tensorflow:global_step/sec: 1.203
# INFO:tensorflow:loss = 0.441114, step = 19250 (83.126 sec)
# INFO:tensorflow:global_step/sec: 1.20619
# INFO:tensorflow:loss = 0.27218306, step = 19350 (82.906 sec)
# INFO:tensorflow:global_step/sec: 1.206
# INFO:tensorflow:loss = 0.29629362, step = 19450 (82.919 sec)
# INFO:tensorflow:Saving checkpoints for 19464 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18474
# INFO:tensorflow:loss = 0.484052, step = 19550 (84.407 sec)
# INFO:tensorflow:global_step/sec: 1.20597
# INFO:tensorflow:loss = 0.43288013, step = 19650 (82.921 sec)
# INFO:tensorflow:global_step/sec: 1.20538
# INFO:tensorflow:loss = 0.6054693, step = 19750 (82.961 sec)
# INFO:tensorflow:global_step/sec: 1.2046
# INFO:tensorflow:loss = 0.34862494, step = 19850 (83.015 sec)
# INFO:tensorflow:global_step/sec: 1.20443
# INFO:tensorflow:loss = 0.158655, step = 19950 (83.027 sec)
# INFO:tensorflow:global_step/sec: 1.20313
# INFO:tensorflow:loss = 0.4067611, step = 20050 (83.117 sec)
# INFO:tensorflow:global_step/sec: 1.20646
# INFO:tensorflow:loss = 0.36416322, step = 20150 (82.887 sec)
# INFO:tensorflow:Saving checkpoints for 20186 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.1867
# INFO:tensorflow:loss = 0.4829383, step = 20250 (84.267 sec)
# INFO:tensorflow:global_step/sec: 1.20344
# INFO:tensorflow:loss = 0.3488092, step = 20350 (83.095 sec)
# INFO:tensorflow:global_step/sec: 1.20387
# INFO:tensorflow:loss = 0.41085312, step = 20450 (83.065 sec)
# INFO:tensorflow:global_step/sec: 1.20465
# INFO:tensorflow:loss = 0.3886705, step = 20550 (83.011 sec)
# INFO:tensorflow:Saving checkpoints for 20625 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.43502924.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-06:44:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-20625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-06:46:01
# INFO:tensorflow:Saving dict for global step 20625: accuracy = 0.8615625, global_step = 20625, loss = 0.37519088
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-20625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20626 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.1229112, step = 20625
# INFO:tensorflow:global_step/sec: 1.10665
# INFO:tensorflow:loss = 0.41593897, step = 20725 (90.363 sec)
# INFO:tensorflow:global_step/sec: 1.20515
# INFO:tensorflow:loss = 0.31571692, step = 20825 (82.977 sec)
# INFO:tensorflow:global_step/sec: 1.20514
# INFO:tensorflow:loss = 0.40356094, step = 20925 (82.978 sec)
# INFO:tensorflow:global_step/sec: 1.20346
# INFO:tensorflow:loss = 0.44351915, step = 21025 (83.094 sec)
# INFO:tensorflow:global_step/sec: 1.20667
# INFO:tensorflow:loss = 0.25540006, step = 21125 (82.872 sec)
# INFO:tensorflow:global_step/sec: 1.20366
# INFO:tensorflow:loss = 0.47689068, step = 21225 (83.080 sec)
# INFO:tensorflow:global_step/sec: 1.20472
# INFO:tensorflow:loss = 0.23064448, step = 21325 (83.007 sec)
# INFO:tensorflow:Saving checkpoints for 21339 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18863
# INFO:tensorflow:loss = 0.44925058, step = 21425 (84.131 sec)
# INFO:tensorflow:global_step/sec: 1.20626
# INFO:tensorflow:loss = 0.17154115, step = 21525 (82.901 sec)
# INFO:tensorflow:global_step/sec: 1.20418
# INFO:tensorflow:loss = 0.27902266, step = 21625 (83.045 sec)
# INFO:tensorflow:global_step/sec: 1.20457
# INFO:tensorflow:loss = 0.20688221, step = 21725 (83.017 sec)
# INFO:tensorflow:global_step/sec: 1.20702
# INFO:tensorflow:loss = 0.14966151, step = 21825 (82.849 sec)
# INFO:tensorflow:global_step/sec: 1.20482
# INFO:tensorflow:loss = 0.20785967, step = 21925 (83.000 sec)
# INFO:tensorflow:global_step/sec: 1.20314
# INFO:tensorflow:loss = 0.28229836, step = 22025 (83.116 sec)
# INFO:tensorflow:Saving checkpoints for 22061 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18526
# INFO:tensorflow:loss = 0.22472808, step = 22125 (84.369 sec)
# INFO:tensorflow:global_step/sec: 1.20481
# INFO:tensorflow:loss = 0.14439367, step = 22225 (83.001 sec)
# INFO:tensorflow:global_step/sec: 1.20676
# INFO:tensorflow:loss = 0.24528004, step = 22325 (82.866 sec)
# INFO:tensorflow:global_step/sec: 1.2061
# INFO:tensorflow:loss = 0.44558412, step = 22425 (82.912 sec)
# INFO:tensorflow:Saving checkpoints for 22500 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3785882.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-07:13:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-22500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-07:14:21
# INFO:tensorflow:Saving dict for global step 22500: accuracy = 0.86125, global_step = 22500, loss = 0.3649759
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-22500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 22501 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.40661842, step = 22500
# INFO:tensorflow:global_step/sec: 1.09976
# INFO:tensorflow:loss = 0.414713, step = 22600 (90.930 sec)
# INFO:tensorflow:global_step/sec: 1.20608
# INFO:tensorflow:loss = 0.4248504, step = 22700 (82.913 sec)
# INFO:tensorflow:global_step/sec: 1.20537
# INFO:tensorflow:loss = 0.425878, step = 22800 (82.962 sec)
# INFO:tensorflow:global_step/sec: 1.20195
# INFO:tensorflow:loss = 0.3266775, step = 22900 (83.198 sec)
# INFO:tensorflow:global_step/sec: 1.20319
# INFO:tensorflow:loss = 0.46399426, step = 23000 (83.112 sec)
# INFO:tensorflow:global_step/sec: 1.20286
# INFO:tensorflow:loss = 0.44305307, step = 23100 (83.135 sec)
# INFO:tensorflow:global_step/sec: 1.20606
# INFO:tensorflow:loss = 0.36815584, step = 23200 (82.915 sec)
# INFO:tensorflow:Saving checkpoints for 23213 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18578
# INFO:tensorflow:loss = 0.3870983, step = 23300 (84.332 sec)
# INFO:tensorflow:global_step/sec: 1.20375
# INFO:tensorflow:loss = 0.3137818, step = 23500 (83.074 sec)
# INFO:tensorflow:global_step/sec: 1.20558
# INFO:tensorflow:loss = 0.25437817, step = 23600 (82.948 sec)
# INFO:tensorflow:global_step/sec: 1.2047
# INFO:tensorflow:loss = 0.26042366, step = 23700 (83.008 sec)
# INFO:tensorflow:global_step/sec: 1.20456
# INFO:tensorflow:loss = 0.5834118, step = 23800 (83.018 sec)
# INFO:tensorflow:global_step/sec: 1.20344
# INFO:tensorflow:loss = 0.48601204, step = 23900 (83.095 sec)
# INFO:tensorflow:Saving checkpoints for 23935 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.1861
# INFO:tensorflow:loss = 0.25081304, step = 24000 (84.310 sec)
# INFO:tensorflow:global_step/sec: 1.20459
# INFO:tensorflow:loss = 0.40297264, step = 24100 (83.016 sec)
# INFO:tensorflow:global_step/sec: 1.20416
# INFO:tensorflow:loss = 0.29643035, step = 24200 (83.045 sec)
# INFO:tensorflow:global_step/sec: 1.20244
# INFO:tensorflow:loss = 0.41559228, step = 24300 (83.165 sec)
# INFO:tensorflow:Saving checkpoints for 24375 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.21305269.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-07:41:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-24375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-07:42:43
# INFO:tensorflow:Saving dict for global step 24375: accuracy = 0.86125, global_step = 24375, loss = 0.35327664
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-24375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24376 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.36901793, step = 24375
# INFO:tensorflow:global_step/sec: 1.11015
# INFO:tensorflow:loss = 0.31101757, step = 24475 (90.079 sec)
# INFO:tensorflow:global_step/sec: 1.20536
# INFO:tensorflow:loss = 0.22993556, step = 24575 (82.963 sec)
# INFO:tensorflow:global_step/sec: 1.20553
# INFO:tensorflow:loss = 0.36955422, step = 24675 (82.951 sec)
# INFO:tensorflow:global_step/sec: 1.20519
# INFO:tensorflow:loss = 0.3606028, step = 24775 (82.975 sec)
# INFO:tensorflow:global_step/sec: 1.20408
# INFO:tensorflow:loss = 0.2646373, step = 24875 (83.051 sec)
# INFO:tensorflow:global_step/sec: 1.20483
# INFO:tensorflow:loss = 0.33541888, step = 24975 (82.999 sec)
# INFO:tensorflow:global_step/sec: 1.20439
# INFO:tensorflow:loss = 0.33000177, step = 25075 (83.029 sec)
# INFO:tensorflow:Saving checkpoints for 25089 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18607
# INFO:tensorflow:loss = 0.35920802, step = 25175 (84.312 sec)
# INFO:tensorflow:global_step/sec: 1.20369
# INFO:tensorflow:loss = 0.28591207, step = 25275 (83.078 sec)
# INFO:tensorflow:global_step/sec: 1.20338
# INFO:tensorflow:loss = 0.43119818, step = 25375 (83.099 sec)
# INFO:tensorflow:global_step/sec: 1.20187
# INFO:tensorflow:loss = 0.22826001, step = 25475 (83.204 sec)
# INFO:tensorflow:global_step/sec: 1.20275
# INFO:tensorflow:loss = 0.20367585, step = 25575 (83.143 sec)
# INFO:tensorflow:global_step/sec: 1.20314
# INFO:tensorflow:loss = 0.29765618, step = 25675 (83.116 sec)
# INFO:tensorflow:global_step/sec: 1.20586
# INFO:tensorflow:loss = 0.6057689, step = 25775 (82.928 sec)
# INFO:tensorflow:Saving checkpoints for 25810 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18446
# INFO:tensorflow:loss = 0.21177948, step = 25875 (84.426 sec)
# INFO:tensorflow:global_step/sec: 1.20452
# INFO:tensorflow:loss = 0.26178685, step = 25975 (83.021 sec)
# INFO:tensorflow:global_step/sec: 1.20374
# INFO:tensorflow:loss = 0.45837408, step = 26075 (83.074 sec)
# INFO:tensorflow:global_step/sec: 1.20511
# INFO:tensorflow:loss = 0.3136651, step = 26175 (82.981 sec)
# INFO:tensorflow:Saving checkpoints for 26250 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.2603788.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-08:09:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-26250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-08:11:03
# INFO:tensorflow:Saving dict for global step 26250: accuracy = 0.8725, global_step = 26250, loss = 0.34118336
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-26250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 26251 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.17412795, step = 26250
# INFO:tensorflow:global_step/sec: 1.10605
# INFO:tensorflow:loss = 0.43967062, step = 26350 (90.412 sec)
# INFO:tensorflow:global_step/sec: 1.20113
# INFO:tensorflow:loss = 0.38839698, step = 26450 (83.255 sec)
# INFO:tensorflow:global_step/sec: 1.20446
# INFO:tensorflow:loss = 0.46572924, step = 26550 (83.024 sec)
# INFO:tensorflow:global_step/sec: 1.20596
# INFO:tensorflow:loss = 0.22703688, step = 26650 (82.922 sec)
# INFO:tensorflow:global_step/sec: 1.20663
# INFO:tensorflow:loss = 0.19690187, step = 26750 (82.875 sec)
# INFO:tensorflow:global_step/sec: 1.20739
# INFO:tensorflow:loss = 0.4541081, step = 26850 (82.823 sec)
# INFO:tensorflow:global_step/sec: 1.20254
# INFO:tensorflow:loss = 0.25210887, step = 26950 (83.157 sec)
# INFO:tensorflow:Saving checkpoints for 26964 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18779
# INFO:tensorflow:loss = 0.46704584, step = 27050 (84.190 sec)
# INFO:tensorflow:global_step/sec: 1.20591
# INFO:tensorflow:loss = 0.46008676, step = 27150 (82.925 sec)
# INFO:tensorflow:global_step/sec: 1.20569
# INFO:tensorflow:loss = 0.4692116, step = 27250 (82.940 sec)
# INFO:tensorflow:global_step/sec: 1.20442
# INFO:tensorflow:loss = 0.41498604, step = 27350 (83.028 sec)
# INFO:tensorflow:global_step/sec: 1.20655
# INFO:tensorflow:loss = 0.33217582, step = 27450 (82.881 sec)
# INFO:tensorflow:global_step/sec: 1.20487
# INFO:tensorflow:loss = 0.21856707, step = 27550 (82.996 sec)
# INFO:tensorflow:global_step/sec: 1.2045
# INFO:tensorflow:loss = 0.5061006, step = 27650 (83.022 sec)
# INFO:tensorflow:Saving checkpoints for 27686 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18793
# INFO:tensorflow:loss = 0.11689255, step = 27750 (84.180 sec)
# INFO:tensorflow:global_step/sec: 1.20527
# INFO:tensorflow:loss = 0.41728827, step = 27850 (82.970 sec)
# INFO:tensorflow:global_step/sec: 1.2059
# INFO:tensorflow:loss = 0.35621697, step = 27950 (82.925 sec)
# INFO:tensorflow:global_step/sec: 1.20305
# INFO:tensorflow:loss = 0.12298201, step = 28050 (83.122 sec)
# INFO:tensorflow:Saving checkpoints for 28125 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.24312189.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-08:38:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-28125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-08:39:25
# INFO:tensorflow:Saving dict for global step 28125: accuracy = 0.8709375, global_step = 28125, loss = 0.33758098
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-28125
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 28126 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.19208089, step = 28125
# INFO:tensorflow:global_step/sec: 1.10817
# INFO:tensorflow:loss = 0.110174984, step = 28225 (90.240 sec)
# INFO:tensorflow:global_step/sec: 1.2066
# INFO:tensorflow:loss = 0.26752263, step = 28325 (82.877 sec)
# INFO:tensorflow:global_step/sec: 1.20669
# INFO:tensorflow:loss = 0.45790207, step = 28425 (82.871 sec)
# INFO:tensorflow:global_step/sec: 1.20517
# INFO:tensorflow:loss = 0.2645071, step = 28525 (82.976 sec)
# INFO:tensorflow:global_step/sec: 1.20456
# INFO:tensorflow:loss = 0.18614268, step = 28625 (83.017 sec)
# INFO:tensorflow:global_step/sec: 1.2026
# INFO:tensorflow:loss = 0.31549937, step = 28725 (83.153 sec)
# INFO:tensorflow:global_step/sec: 1.2032
# INFO:tensorflow:loss = 0.32032448, step = 28825 (83.112 sec)
# INFO:tensorflow:Saving checkpoints for 28839 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18716
# INFO:tensorflow:loss = 0.37035736, step = 28925 (84.235 sec)
# INFO:tensorflow:global_step/sec: 1.2029
# INFO:tensorflow:loss = 0.19133434, step = 29025 (83.132 sec)
# INFO:tensorflow:global_step/sec: 1.20257
# INFO:tensorflow:loss = 0.35171002, step = 29125 (83.155 sec)
# INFO:tensorflow:global_step/sec: 1.20315
# INFO:tensorflow:loss = 0.24197486, step = 29225 (83.115 sec)
# INFO:tensorflow:global_step/sec: 1.20378
# INFO:tensorflow:loss = 0.17264554, step = 29325 (83.072 sec)
# INFO:tensorflow:global_step/sec: 1.20362
# INFO:tensorflow:loss = 0.25561213, step = 29425 (83.083 sec)
# INFO:tensorflow:global_step/sec: 1.20527
# INFO:tensorflow:loss = 0.1891387, step = 29525 (82.969 sec)
# INFO:tensorflow:Saving checkpoints for 29560 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18601
# INFO:tensorflow:loss = 0.3285517, step = 29625 (84.317 sec)
# INFO:tensorflow:global_step/sec: 1.20491
# INFO:tensorflow:loss = 0.21977106, step = 29725 (82.994 sec)
# INFO:tensorflow:global_step/sec: 1.20412
# INFO:tensorflow:loss = 0.2544833, step = 29825 (83.048 sec)
# INFO:tensorflow:global_step/sec: 1.20518
# INFO:tensorflow:loss = 0.26932096, step = 29925 (82.975 sec)
# INFO:tensorflow:Saving checkpoints for 30000 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16110992.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-09:06:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-09:07:47
# INFO:tensorflow:Saving dict for global step 30000: accuracy = 0.875625, global_step = 30000, loss = 0.33366188
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 30001 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.05578544, step = 30000
# INFO:tensorflow:global_step/sec: 1.10766
# INFO:tensorflow:loss = 0.4136641, step = 30100 (90.281 sec)
# INFO:tensorflow:global_step/sec: 1.20432
# INFO:tensorflow:loss = 0.43376487, step = 30200 (83.034 sec)
# INFO:tensorflow:global_step/sec: 1.20718
# INFO:tensorflow:loss = 0.2757851, step = 30300 (82.837 sec)
# INFO:tensorflow:global_step/sec: 1.20772
# INFO:tensorflow:loss = 0.17693914, step = 30400 (82.801 sec)
# INFO:tensorflow:global_step/sec: 1.20522
# INFO:tensorflow:loss = 0.49545583, step = 30500 (82.972 sec)
# INFO:tensorflow:global_step/sec: 1.20544
# INFO:tensorflow:loss = 0.33637777, step = 30600 (82.959 sec)
# INFO:tensorflow:global_step/sec: 1.20558
# INFO:tensorflow:loss = 0.34123832, step = 30700 (82.947 sec)
# INFO:tensorflow:Saving checkpoints for 30714 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18607
# INFO:tensorflow:loss = 0.35868633, step = 30800 (84.312 sec)
# INFO:tensorflow:global_step/sec: 1.2054
# INFO:tensorflow:loss = 0.24659084, step = 30900 (82.960 sec)
# INFO:tensorflow:global_step/sec: 1.20639
# INFO:tensorflow:loss = 0.26122588, step = 31000 (82.892 sec)
# INFO:tensorflow:global_step/sec: 1.20327
# INFO:tensorflow:loss = 0.16863188, step = 31100 (83.107 sec)
# INFO:tensorflow:global_step/sec: 1.2052
# INFO:tensorflow:loss = 0.23501965, step = 31200 (82.974 sec)
# INFO:tensorflow:global_step/sec: 1.20645
# INFO:tensorflow:loss = 0.40870386, step = 31300 (82.888 sec)
# INFO:tensorflow:global_step/sec: 1.20674
# INFO:tensorflow:loss = 0.39099568, step = 31400 (82.868 sec)
# INFO:tensorflow:Saving checkpoints for 31436 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18472
# INFO:tensorflow:loss = 0.16315766, step = 31500 (84.408 sec)
# INFO:tensorflow:global_step/sec: 1.20577
# INFO:tensorflow:loss = 0.2216576, step = 31600 (82.935 sec)
# INFO:tensorflow:global_step/sec: 1.2049
# INFO:tensorflow:loss = 0.23107074, step = 31700 (82.994 sec)
# INFO:tensorflow:global_step/sec: 1.20542
# INFO:tensorflow:loss = 0.2532777, step = 31800 (82.959 sec)
# INFO:tensorflow:Saving checkpoints for 31875 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.35196677.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-19-09:34:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-31875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-19-09:36:07
# INFO:tensorflow:Saving dict for global step 31875: accuracy = 0.87, global_step = 31875, loss = 0.34150636
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/simplereluoffnet32x20/model.ckpt-31875
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 31876 into models/simplereluoffnet32x20/model.ckpt.
# INFO:tensorflow:loss = 0.45097747, step = 31875
# INFO:tensorflow:global_step/sec: 1.10843
# INFO:tensorflow:loss = 0.2637552, step = 31975 (90.218 sec)
# INFO:tensorflow:global_step/sec: 1.2051
# INFO:tensorflow:loss = 0.3068946, step = 32075 (82.980 sec)
# INFO:tensorflow:global_step/sec: 1.20452
# INFO:tensorflow:loss = 0.18894084, step = 32175 (83.020 sec)
# INFO:tensorflow:global_step/sec: 1.20404
# INFO:tensorflow:loss = 0.19203795, step = 32275 (83.054 sec)

# %%
# estimator.evaluate(input_fn=lambda:tf.data.Dataset.from_tensor_slices(testing_data).batch(3).take(1))

# %%
# tuple(estimator.predict(input_fn=lambda:tf.data.Dataset.from_tensor_slices(testing_data).batch(3).take(1)))

# %%
# estimator.train(input_fn=training_dataset, steps=1)
